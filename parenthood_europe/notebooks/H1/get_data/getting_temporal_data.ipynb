# %%
import pandas as pd

df = pd.read_excel('../../../data/H1_analysis/has_cv_url.xlsx')
df
# Out:
#              ResponseId                                       DE13c_1_TEXT  \
# 0           Response ID  We acknowledge your privacy considerations. Wo...
# 1     R_77h3lBm8zYTS5a1                                                NaN
# 2     R_4pD7OrlAt0l6mjL                                                NaN
# 3     R_7OE9SfkJJ6q9jbP                                                NaN
# 4     R_11v7OTVCxgOhPWb                                                NaN
# ...                 ...                                                ...
# 3231  R_2PV7RhvMAMP0hcR                                                NaN
# 3232  R_2WwaSOfdPYRwAwN                                                NaN
# 3233  R_2w60Oo6hzaQimqC                                                NaN
# 3234  R_2iFjsLGZX3qEgu0                                                NaN
# 3235  R_8q4Lj3sJmvaDKsU                                                NaN
#
#                                              DE13a_Name  \
# 0     As part of this study, we aim to gain insights...
# 1                                     LisetteMunzCV.pdf
# 2                                                   NaN
# 3                                                   NaN
# 4                                          ORCID ID.txt
# ...                                                 ...
# 3231                                      CV_MWijga.pdf
# 3232                                                NaN
# 3233                                                NaN
# 3234                                                NaN
# 3235                             2024 ALTREUTHER CV.pdf
#
#                                                DE13_1_1  \
# 0     Or if you prefer, you can also share your onli...
# 1                                                   NaN
# 2     https://scholar.google.com/citations?user=Guhy...
# 3     https://scholar.google.com/citations?user=BSke...
# 4                                                   NaN
# ...                                                 ...
# 3231                                                NaN
# 3232                                                NaN
# 3233  https://scholar.google.co.uk/citations?user=Wi...
# 3234  https://scholar.google.com/citations?hl=en&use...
# 3235                                                NaN
#
#                                                DE13_2_1  \
# 0     Or if you prefer, you can also share your onli...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3231                                                NaN
# 3232                                0000-0003-1891-7522
# 3233                                                NaN
# 3234              https://orcid.org/0000-0002-9203-7550
# 3235                                                NaN
#
#                                                DE13_3_1  \
# 0     Or if you prefer, you can also share your onli...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3231                                                NaN
# 3232                                                NaN
# 3233                                                NaN
# 3234    https://www.researchgate.net/profile/Elif-Calik
# 3235                                                NaN
#
#                                                DE13_4_1  \
# 0     Or if you prefer, you can also share your onli...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3231                                                NaN
# 3232                                                NaN
# 3233                                                NaN
# 3234  https://www.webofscience.com/wos/woscc/basic-s...
# 3235                                                NaN
#
#                                                DE13_5_1  \
# 0     Or if you prefer, you can also share your onli...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3231                                                NaN
# 3232                                                NaN
# 3233                                                NaN
# 3234  https://www.scopus.com/authid/detail.uri?autho...
# 3235                                                NaN
#
#                                               DE14_11_1  \
# 0     Or if you prefer, you can also share your onli...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3231                                                NaN
# 3232                                                NaN
# 3233                                                NaN
# 3234                                                NaN
# 3235                                                NaN
#
#                                                DE13_6_1
# 0     Or if you prefer, you can also share your onli...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3231                                                NaN
# 3232                                                NaN
# 3233                                                NaN
# 3234                                                NaN
# 3235                                                NaN
#
# [3236 rows x 10 columns]

# %%
df = df.drop(columns=["DE13c_1_TEXT"])

# %%
df_data = df.iloc[1:]

available_cvs = df_data['DE13a_Name'].notna().sum()
print(f"{available_cvs} CVs")

available_gscholar = df_data['DE13_1_1'].notna().sum()
print(f"{available_gscholar} Google Scholar accounts")

available_orcid = df_data['DE13_2_1'].notna().sum()
print(f"{available_orcid} Orcids")

available_rgate = df_data['DE13_3_1'].notna().sum()
print(f"{available_rgate} Research Gate accounts")

available_wscience = df_data['DE13_4_1'].notna().sum()
print(f"{available_wscience} Web of Science accounts")

available_scopus = df_data['DE13_5_1'].notna().sum()
print(f"{available_scopus} Scopus accounts")

available_oalex = df_data['DE14_11_1'].notna().sum()
print(f"{available_oalex} OpenAlex profiles found")

available_otherurl = df_data['DE13_6_1'].notna().sum()
print(f"{available_otherurl} other URLs found")
# Out:
# 1177 CVs
# 928 Google Scholar accounts
# 1242 Orcids
# 401 Research Gate accounts
# 103 Web of Science accounts
# 180 Scopus accounts
# 7 OpenAlex profiles found
# 243 other URLs found

# %%
# List of profile columns
profile_cols = [
    'DE13a_Name',     # CVs
    'DE13_1_1',       # Google Scholar
    'DE13_2_1',       # ORCID
    'DE13_3_1',       # ResearchGate
    'DE13_4_1',       # Web of Science
    'DE13_5_1',       # Scopus
    'DE14_11_1',      # OpenAlex
    'DE13_6_1',       # Other URLs
]

# Subset of the data
df_profiles = df_data[profile_cols]

# Count of unique respondents with at least one profile
respondents_with_any_profile = df_profiles.notna().any(axis=1).sum()
print(f"{respondents_with_any_profile} researchers provided at least one academic profile or URL.")
# Out:
# 3235 researchers provided at least one academic profile or URL.

# %%
import plotly.express as px

def plot_profile_availability_pie(counts_dict, total_profiles):
    labels = list(counts_dict.keys())
    values = list(counts_dict.values())

    color_sequence = [
        "#D7D9B1",  # Orcid
        "#3A6992",  # CVs
        "#BB4430",  # Google Scholar
        "#795663",  # ResearchGate
        "#808F85",  # Other URLs
        "#B89685",  # Scopus
        "#C3D3E5",  # Web of Science
        "#A7C6ED",  # OpenAlex
    ]

    fig = px.pie(
        names=labels,
        values=values,
        title=f"Availability of Academic Profiles<br><sup>{total_profiles} researchers provided at least one profile</sup>",
        hole=0,
        color=labels,
        color_discrete_sequence=color_sequence
    )

    fig.update_traces(
        textinfo='percent+label',
        textfont_size=12,
        #marker=dict(line=dict(color='#000000', width=0.5))  # thin border
    )

    fig.update_layout(
        showlegend=True,
        legend_title="",
        width=800,
        height=550,
    )

    return fig

# %%
counts_dict = {
    "CVs": available_cvs,
    "Google Scholar": available_gscholar,
    "Orcid": available_orcid,
    "ResearchGate": available_rgate,
    "Web of Science": available_wscience,
    "Scopus": available_scopus,
    "OpenAlex": available_oalex,
    "Other URLs": available_otherurl,
}

profile_cols = [
    "DE13a_Name",
    "DE13_1_1", "DE13_2_1", "DE13_3_1", "DE13_4_1",
    "DE13_5_1", "DE13_6_1", "DE14_11_1"
]

total_profiles = df_data[profile_cols].notna().any(axis=1).sum()

fig = plot_profile_availability_pie(counts_dict, total_profiles)
fig.show()

# %%
fig.write_html("academic_profiles_pie.html")

# %% [markdown]
# ## 1. ORCIDs

# %% [markdown]
# I will go through each provided datatype in decreasing order by highest number given.
# First I will clean the ORCID Ids and bring them into the format required by Open Alex' API: orcid:
# https://orcid.org/0000-0001-6187-6610.

# %%
orcid_df = df_data.loc[df_data['DE13_2_1'].notna(), ['ResponseId', 'DE13_2_1']]
orcid_df
# Out:
#              ResponseId                               DE13_2_1
# 6     R_2DUIfkur5fbOgZo                    0000-0001-5041-5018
# 12    R_46yreKgPLBawn3H                    0000-0002-2763-0921
# 13    R_2ZTGtufLu3KUHW9                       0000000181844747
# 15    R_1gzm4gKhyxKNWBW  http://orcid.org/0000-0002-2475-1496
# 16    R_3w5HE5P6WKA3ErS  https://orcid.org/0000-0002-8785-8063
# ...                 ...                                    ...
# 3218  R_216eipKa8MqFn3z  https://orcid.org/0000-0002-6409-2632
# 3219  R_8FlyCLCDJMPasD4  https://orcid.org/0000-0002-6873-2967
# 3228  R_2X0fTWPBw20QquW                    0000-0003-1528-8185
# 3232  R_2WwaSOfdPYRwAwN                    0000-0003-1891-7522
# 3234  R_2iFjsLGZX3qEgu0  https://orcid.org/0000-0002-9203-7550
#
# [1242 rows x 2 columns]

# %%
failed_orcid_extractions = orcid_df[orcid_df['DE13_2_1'].isna()]
print(f"{len(failed_orcid_extractions)} failed ORCID extractions")
# Out:
# 0 failed ORCID extractions

# %%
import re

def extract_canonical_orcid(value):
    value = str(value).strip()

    # Match dashed ORCID: 0000-0000-0000-0000 or ...-000X
    dashed = re.search(r'\d{4}-\d{4}-\d{4}-\d{3}[\dX]', value)
    if dashed:
        return f'https://orcid.org/{dashed.group(0)}'

    # Get raw 16-character ORCID: 15 digits + digit or X, and add dashes
    raw = re.search(r'\d{15}[\dX]', value)
    if raw:
        digits = raw.group(0)
        formatted = f'{digits[:4]}-{digits[4:8]}-{digits[8:12]}-{digits[12:]}'
        return f'https://orcid.org/{formatted}'

    # Everything else is ignored
    return None

# %%
orcid_df['orcid_standard'] = orcid_df['DE13_2_1'].apply(extract_canonical_orcid)
orcid_df
# Out:
#              ResponseId                               DE13_2_1  \
# 6     R_2DUIfkur5fbOgZo                    0000-0001-5041-5018
# 12    R_46yreKgPLBawn3H                    0000-0002-2763-0921
# 13    R_2ZTGtufLu3KUHW9                       0000000181844747
# 15    R_1gzm4gKhyxKNWBW  http://orcid.org/0000-0002-2475-1496
# 16    R_3w5HE5P6WKA3ErS  https://orcid.org/0000-0002-8785-8063
# ...                 ...                                    ...
# 3218  R_216eipKa8MqFn3z  https://orcid.org/0000-0002-6409-2632
# 3219  R_8FlyCLCDJMPasD4  https://orcid.org/0000-0002-6873-2967
# 3228  R_2X0fTWPBw20QquW                    0000-0003-1528-8185
# 3232  R_2WwaSOfdPYRwAwN                    0000-0003-1891-7522
# 3234  R_2iFjsLGZX3qEgu0  https://orcid.org/0000-0002-9203-7550
#
#                              orcid_standard
# 6     https://orcid.org/0000-0001-5041-5018
# 12    https://orcid.org/0000-0002-2763-0921
# 13    https://orcid.org/0000-0001-8184-4747
# 15    https://orcid.org/0000-0002-2475-1496
# 16    https://orcid.org/0000-0002-8785-8063
# ...                                     ...
# 3218  https://orcid.org/0000-0002-6409-2632
# 3219  https://orcid.org/0000-0002-6873-2967
# 3228  https://orcid.org/0000-0003-1528-8185
# 3232  https://orcid.org/0000-0003-1891-7522
# 3234  https://orcid.org/0000-0002-9203-7550
#
# [1242 rows x 3 columns]

# %%
failed_orcid_extractions = orcid_df[orcid_df['orcid_standard'].isna()]
print(f"{len(failed_orcid_extractions)} failed ORCID extractions")
# Out:
# 17 failed ORCID extractions

# %%
# I want to see the failed entries with original inputs
failed_orcid_extractions[['ResponseId', 'DE13_2_1']]
# Out:
#              ResponseId                                           DE13_2_1
# 29    R_4bHw34dQzUp3iPj                                    000000280613629
# 59    R_8YXmB75YGiuDUY4                                            2151684
# 1059  R_8kIvX5bxd8oEBuW  https://orcid.org/orcid-search/search?searchQu...
# 1068  R_2JKPy8nLPXl4GfT                                   0-0002-1525-5255
# 1234  R_2Ev6eGbhRDAGMUA                                  0000-0002-8988-81
# 1358  R_2KJgavGjIMAE5RD             We recommend that health advertisers:
# 1365  R_20tMEnRIJCDG0No  https://orcid.org/orcid-search/search?searchQu...
# 1436  R_8bIVRT6jaNhc7Ox                                                  2
# 1705  R_6flVGEkboDnwB3E                              0000-0002- 2652- 772X
# 1795  R_2q8htRVaqOC3XNb      https://doi.org/10.1080/02680939.2022.2067594
# 2107  R_81gfuFx8ir2JbJ7                                0000-0001-7399-717x
# 2385  R_8bK3iRDHBGuYulK                                        1 8091 9014
# 2653  R_8Djeh9O5o9MfDnS  https://pure.courtauld.ac.uk/en/persons/tom-ni...
# 2826  R_2JEtHxARk28okho                                 000-0002-3177-6026
# 2887  R_81NJgXINQgcbhMt                                        00000022499
# 2975  R_2TBHnWk3hdrfkom  https://scholar.google.com/citations?user=r0bB...
# 3047  R_8ery8MZOlUg82g1                                     0002-3523-8102

# %%
orcid_df_clean = orcid_df[orcid_df['orcid_standard'].notna()]

# %%
orcid_df_clean
# Out:
#              ResponseId                               DE13_2_1  \
# 6     R_2DUIfkur5fbOgZo                    0000-0001-5041-5018
# 12    R_46yreKgPLBawn3H                    0000-0002-2763-0921
# 13    R_2ZTGtufLu3KUHW9                       0000000181844747
# 15    R_1gzm4gKhyxKNWBW  http://orcid.org/0000-0002-2475-1496
# 16    R_3w5HE5P6WKA3ErS  https://orcid.org/0000-0002-8785-8063
# ...                 ...                                    ...
# 3218  R_216eipKa8MqFn3z  https://orcid.org/0000-0002-6409-2632
# 3219  R_8FlyCLCDJMPasD4  https://orcid.org/0000-0002-6873-2967
# 3228  R_2X0fTWPBw20QquW                    0000-0003-1528-8185
# 3232  R_2WwaSOfdPYRwAwN                    0000-0003-1891-7522
# 3234  R_2iFjsLGZX3qEgu0  https://orcid.org/0000-0002-9203-7550
#
#                              orcid_standard
# 6     https://orcid.org/0000-0001-5041-5018
# 12    https://orcid.org/0000-0002-2763-0921
# 13    https://orcid.org/0000-0001-8184-4747
# 15    https://orcid.org/0000-0002-2475-1496
# 16    https://orcid.org/0000-0002-8785-8063
# ...                                     ...
# 3218  https://orcid.org/0000-0002-6409-2632
# 3219  https://orcid.org/0000-0002-6873-2967
# 3228  https://orcid.org/0000-0003-1528-8185
# 3232  https://orcid.org/0000-0003-1891-7522
# 3234  https://orcid.org/0000-0002-9203-7550
#
# [1225 rows x 3 columns]

# %% [markdown]
# ORCID is done. Now, CVs.

# %% [markdown]
# ## 2. CVs

# %%
cv_df = df_data.loc[df_data['DE13a_Name'].notna(), ['ResponseId', 'DE13a_Name']]
cv_df
# Out:
#              ResponseId                                         DE13a_Name
# 1     R_77h3lBm8zYTS5a1                                  LisetteMunzCV.pdf
# 4     R_11v7OTVCxgOhPWb                                       ORCID ID.txt
# 5     R_7NX1r2rWq9dYcBb                                        cvn2023.pdf
# 8     R_22Qq9pPVMQRrRG9  Baggio Guido- CV (April 2024)_without personal...
# 9     R_7eEOvE9UAAotmHQ                                             CV.pdf
# ...                 ...                                                ...
# 3224  R_8qglyjMvsVrSFlh                                CV_ROUIF S 2024.pdf
# 3225  R_2qWALiMolFEfkpb            curriculum_vitae_AmandaSCamara_0324.pdf
# 3226  R_8qEZ06rnMlHmddD                    CV Sabine D Zimmermann 2023.pdf
# 3231  R_2PV7RhvMAMP0hcR                                      CV_MWijga.pdf
# 3235  R_8q4Lj3sJmvaDKsU                             2024 ALTREUTHER CV.pdf
#
# [1177 rows x 2 columns]

# %%
num_pdfs = cv_df['DE13a_Name'].str.endswith('.pdf', na=False).sum()
print(f"{num_pdfs} entries in DE13a_Name end with .pdf")

non_pdf_rows = cv_df[~cv_df['DE13a_Name'].str.endswith('.pdf', na=False)]
display(non_pdf_rows)

num_docs = cv_df['DE13a_Name'].str.endswith('.doc', na=False).sum()
num_docxs = cv_df['DE13a_Name'].str.endswith('.docx', na=False).sum()
print(f"{num_docs} entries end with .doc")
print(f"{num_docxs} entries end with .docx")

# Find entries not ending with .pdf, .doc, or .docx
non_standard_rows = cv_df[
    ~cv_df['DE13a_Name'].str.endswith('.pdf', na=False) &
    ~cv_df['DE13a_Name'].str.endswith('.doc', na=False) &
    ~cv_df['DE13a_Name'].str.endswith('.docx', na=False)
]
display(non_standard_rows)
print(f"{len(non_standard_rows)} entries do not end with .pdf, .doc, or .docx")
# Out:
# 803 entries in DE13a_Name end with .pdf
#              ResponseId                                DE13a_Name
# 4     R_11v7OTVCxgOhPWb                              ORCID ID.txt
# 20    R_2zptVVvkyegb6u0           Juris Borzovs CV akred 2021.rtf
# 41    R_198bUqMSHgnPIxX             Alice Reid cv 2023 3 page.doc
# 48    R_2gOdBDgTF157aQp  Curriculum VitaeNicolette de Keizer.docx
# 68    R_8yK0ZAIhgpDxtOV               Harry de Boer May 2024.docx
# ...                 ...                                       ...
# 3199  R_8knQjeKjNEjw61Q                       CV Tahan 2023 .docx
# 3200  R_8ITg6JH3UlR9sB6                    CV_2024_Ian_Taylor.doc
# 3203  R_8q9blJt20asPo50                cv Aldaberdikyzy Aidyn.doc
# 3214  R_4qjqGp5sJgmewId                  PittsCVphysphilwqzu.docx
# 3216  R_8qxIHEWybKMWo01                 ArnfredCV_jan2024_1p.docx
#
# [374 rows x 2 columns]
# 92 entries end with .doc
# 261 entries end with .docx
#              ResponseId                              DE13a_Name
# 4     R_11v7OTVCxgOhPWb                            ORCID ID.txt
# 20    R_2zptVVvkyegb6u0         Juris Borzovs CV akred 2021.rtf
# 161   R_8cjFSnWXh7XspCB                            CV UL2 alias
# 204   R_2QAgyrZH8JTCTaK                            IMG_2743.png
# 322   R_8RjDV5U7TDHKxa1               CV Inglese since 1999.rtf
# 331   R_82Lycq4JdPQMi0K                  CV_Kozarzewski_Eng.DOC
# 491   R_8VqFhIGl8ZoEZIc                                CV.pages
# 794   R_2oL0UsKFORDJH1Y                   CVCSIC, ASP, 2023.rtf
# 1016  R_8BkXLqrekRT8WnF            Curriculum-English-short.odt
# 1186  R_4doRLPHDSUkdRt6              Vikrant Resume 2023 .pages
# 1514  R_2MaV9zsFqPLZKhj          CV_PubList_Grosshans Kopie.rtf
# 1870  R_8zUWNBuAamrMkc3   CV Accueil - Archive ouverte HAL.html
# 2006  R_8mWOOXBI1mlEGUh                                98238[1]
# 2037  R_8dRBV53WQtW0GWZ                                  CV.png
# 2369  R_8dsgvyqwpCOREVM                            ACCOMPLI.DOC
# 2386  R_8DleXL23T7NOSZj              my_cv_is_not_available.txt
# 2397  R_210eYPeHqcHDQ4x  CV - Dr David Smith October 2023.pages
# 2542  R_2NV9HTiQzbPJn1v                        dokuikon_PDF.png
# 2547  R_238HtUbpGduzg4S               CV_MaxSieger_20221110.rtf
# 2636  R_864OQc2H2U0vvlK             Meyer CV September 2023.rtf
# 2776  R_25u9yVrmMPEJ4vj        CV_Dambrauskas_EN.pdf.crdownload
# 21 entries do not end with .pdf, .doc, or .docx

# %% [markdown]
# 3 different data/ file types store 1156 of 1177 CVs provided.
# Let's check now first the other datatypes given, we continue with GoogleScholar accounts.

# %% [markdown]
# ## 3. Google Scholar Accounts

# %%
gs_df = df_data.loc[df_data['DE13_1_1'].notna(), ['ResponseId', 'DE13_1_1']]
gs_df
# Out:
#              ResponseId                                           DE13_1_1
# 2     R_4pD7OrlAt0l6mjL  https://scholar.google.com/citations?user=Guhy...
# 3     R_7OE9SfkJJ6q9jbP  https://scholar.google.com/citations?user=BSke...
# 11    R_62ojVyfY2SdzKN0  https://scholar.google.com/scholar?hl=en&as_sd...
# 23    R_2B4eUokwACUsT08  https://scholar.google.com/citations?user=DCWk...
# 27    R_2JTY94aJonph8Qx  https://scholar.google.it/citations?user=Uyrfi...
# ...                 ...                                                ...
# 3223  R_8oUd1CmnYTMewcw  https://scholar.google.com/citations?user=Q4_A...
# 3227  R_8PXnvStEzBAgC8m  https://scholar.google.com/citations?user=AMLe...
# 3230  R_2sTEG4FLmmU8kOm  https://www.webofscience.com/wos/woscc/basic-s...
# 3233  R_2w60Oo6hzaQimqC  https://scholar.google.co.uk/citations?user=Wi...
# 3234  R_2iFjsLGZX3qEgu0  https://scholar.google.com/citations?hl=en&use...
#
# [928 rows x 2 columns]

# %% [markdown]
# ## 4. Research Gate Accounts

# %%
rg_df = df_data.loc[df_data['DE13_3_1'].notna(), ['ResponseId', 'DE13_3_1']]
rg_df
# Out:
#              ResponseId                                           DE13_3_1
# 15    R_1gzm4gKhyxKNWBW  https://www.researchgate.net/profile/Viktoriia...
# 33    R_1cVUYTnhvznwxvH  https://www.researchgate.net/profile/Vesela-Mi...
# 36    R_2nuEIv4Y0ddIoXF  https://www.researchgate.net/profile/Jean-Bapt...
# 39    R_5c1ZlaLH0DVZDQ5  https://www.researchgate.net/profile/Christian...
# 40    R_7j2LFKfr5BPsJEp  https://www.researchgate.net/profile/Lucia-Bel...
# ...                 ...                                                ...
# 3201  R_82RJ2wuuEfAQI0T  https://www.researchgate.net/profile/Laurie-An...
# 3209  R_8aTvXnZQE8Gef4J  https://www.researchgate.net/profile/Sonia-Alo...
# 3220  R_2QycPSYQFDiOaLs  https://www.researchgate.net/profile/Najeeb-Id...
# 3229  R_8kN3QAWTTK2z87T  https://www.researchgate.net/profile/Joachim-H...
# 3234  R_2iFjsLGZX3qEgu0    https://www.researchgate.net/profile/Elif-Calik
#
# [401 rows x 2 columns]

# %% [markdown]
# ## 5. Web of Science

# %%
ws_df = df_data.loc[df_data['DE13_4_1'].notna(), ['ResponseId', 'DE13_4_1']]
ws_df
# Out:
#              ResponseId                                           DE13_4_1
# 11    R_62ojVyfY2SdzKN0  https://www.webofscience.com/wos/woscc/summary...
# 30    R_8S1zWLINCbSqU7z  https://www.webofscience.com/wos/author/record...
# 33    R_1cVUYTnhvznwxvH  https://www.webofscience.com/wos/author/record...
# 54    R_2kREO1n73i4PZbL  https://www.webofscience.com/wos/author/record...
# 88    R_8oAVfLbXyNOru1A  https://www.webofscience.com/wos/author/record...
# ...                 ...                                                ...
# 2891  R_2KiaAyJIknq2frr  https://www.webofscience.com/wos/author/record...
# 2903  R_8Wk9PLFqi2ETsxr  https://www-webofscience-com.proxy-ub.rug.nl/w...
# 2946  R_2PXalvLF5uWODff  https://www.webofscience.com/wos/author/record...
# 2975  R_2TBHnWk3hdrfkom  https://www.webofscience.com/wos/author/record...
# 3234  R_2iFjsLGZX3qEgu0  https://www.webofscience.com/wos/woscc/basic-s...
#
# [103 rows x 2 columns]

# %% [markdown]
# ## 6. Scopus

# %%
scopus_df = df_data.loc[df_data['DE13_5_1'].notna(), ['ResponseId', 'DE13_5_1']]
scopus_df
# Out:
#              ResponseId                                           DE13_5_1
# 15    R_1gzm4gKhyxKNWBW  https://www.scopus.com/authid/detail.uri?autho...
# 30    R_8S1zWLINCbSqU7z  https://www.scopus.com/authid/detail.uri?autho...
# 33    R_1cVUYTnhvznwxvH  https://www.scopus.com/authid/detail.uri?autho...
# 34    R_22K1UksXA8pHVfq  https://www.scopus.com/authid/detail.uri?autho...
# 54    R_2kREO1n73i4PZbL  https://www.scopus.com/authid/detail.uri?autho...
# ...                 ...                                                ...
# 3144  R_2tDJXr0XU8HlOCQ  https://www.scopus.com/authid/detail.uri?autho...
# 3156  R_2q1rjasYbfm32Tf  https://www.scopus.com/authid/detail.uri?autho...
# 3166  R_25SIA1HKgDT0Eyy  https://www.scopus.com/authid/detail.uri?autho...
# 3209  R_8aTvXnZQE8Gef4J  https://www.scopus.com/authid/detail.uri?autho...
# 3234  R_2iFjsLGZX3qEgu0  https://www.scopus.com/authid/detail.uri?autho...
#
# [180 rows x 2 columns]

# %% [markdown]
# ## 7. Open Alex

# %%
check_other_df = df_data.loc[df_data['DE14_11_1'].notna(), ['ResponseId', 'DE14_11_1']]
check_other_df

# this is open Alex
# Out:
#              ResponseId                                          DE14_11_1
# 656   R_22xkV3z6PwETGMG                                         5004494480
# 1091  R_2TBugvAyOw9Ji3L           https://openalex.org/authors/a5061887578
# 1246  R_8EPWr5kSWlA5pbJ  https://openalex.org/works?page=1&filter=autho...
# 1250  R_86l4dNnNx9I9x9f  https://openalex.org/works?page=3&filter=autho...
# 1436  R_8bIVRT6jaNhc7Ox                                                  0
# 1879  R_8CxoORRcWRV7ztD   https://explore.openalex.org/authors/A5042098918
# 2605  R_26eCwHR26RIk332           https://openalex.org/authors/a5030518831

# %% [markdown]
# Not sure why, but this column has a different Question ID despite being sorted under the right ones... it should actually be DE13_5_1 and asks for an OpenAlex URL.

# %% [markdown]
# ## 8. Other

# %%
own_website_df = df_data.loc[df_data['DE13_6_1'].notna(), ['ResponseId', 'DE13_6_1']]
own_website_df
# Out:
#              ResponseId                                           DE13_6_1
# 7     R_8qkA83d3vwB0Tz7  https://www.jura.hhu.de/lehrstuehle-und-instit...
# 14    R_62GqqdSdFVyfLXa                        uwe staff login zoe brennan
# 27    R_2JTY94aJonph8Qx              https://giuseppevizzari.github.io/cv/
# 29    R_4bHw34dQzUp3iPj  https://centrenorbertelias.cnrs.fr/equipes-de-...
# 56    R_5ZWWEKn1Iyg0OYM                    https://lassev.github.io/cv.pdf
# ...                 ...                                                ...
# 3170  R_8GHOtoMSgu7VABo           https://www.linkedin.com/in/adenambtman/
# 3186  R_2mI7ieWcIWanR9e                  https://www.kth.se/profile/mardal
# 3188  R_2ZYeJxSnpqh8xA5           https://www.etis.ee/CV/Daisy_Volmer/eng/
# 3190  R_8EYyPIZF3EPJ8cj      https://www.zhaw.ch/de/ueber-uns/person/grea/
# 3202  R_8GKAcLcrNJmjLEZ             http://ramonvoges.de/curriculum-vitae/
#
# [243 rows x 2 columns]

# %% [markdown]
# # Scraping Researchers by ORCID on Open Alex

# %%
import requests
import json
import time
import pandas as pd

# %%
def get_author_id(row):
    orcid_id = row['orcid_standard']
    url = f"https://api.openalex.org/authors/{orcid_id}"

    try:
        response = requests.get(url)
        if response.status_code == 200 and response.text.strip(): 
            data = json.loads(response.text)
            time.sleep(0.5)  
            return data
        else:
            return None
    except Exception as e:
        print(f"Error for ORCID {orcid_id}: {e}")
        return None

# %%
# trying with first 5 rows 
sample_df = orcid_df_clean.head(5).copy()
sample_df["retrieved_author_data"] = sample_df.apply(get_author_id, axis=1)
sample_df
# Out:
#            ResponseId                               DE13_2_1  \
# 6   R_2DUIfkur5fbOgZo                    0000-0001-5041-5018
# 12  R_46yreKgPLBawn3H                    0000-0002-2763-0921
# 13  R_2ZTGtufLu3KUHW9                       0000000181844747
# 15  R_1gzm4gKhyxKNWBW  http://orcid.org/0000-0002-2475-1496
# 16  R_3w5HE5P6WKA3ErS  https://orcid.org/0000-0002-8785-8063
#
#                            orcid_standard  \
# 6   https://orcid.org/0000-0001-5041-5018
# 12  https://orcid.org/0000-0002-2763-0921
# 13  https://orcid.org/0000-0001-8184-4747
# 15  https://orcid.org/0000-0002-2475-1496
# 16  https://orcid.org/0000-0002-8785-8063
#
#                                 retrieved_author_data
# 6   {'id': 'https://openalex.org/A5079865836', 'or...
# 12  {'id': 'https://openalex.org/A5061820165', 'or...
# 13  {'id': 'https://openalex.org/A5065296382', 'or...
# 15  {'id': 'https://openalex.org/A5087740005', 'or...
# 16  {'id': 'https://openalex.org/A5043649135', 'or...

# %%
# what is the retrieved content?
first_entry = sample_df['retrieved_author_data'].iloc[0]
print(json.dumps(first_entry, indent=2))
# Out:
# {
#   "id": "https://openalex.org/A5079865836",
#   "orcid": "https://orcid.org/0000-0001-5041-5018",
#   "display_name": "Ericka Johnson",
#   "display_name_alternatives": [
#     "Alice K. Johnson",
#     "Ericka Johnson",
#     "Austin Jerome Johnson",
#     "E. Johnson",
#     "A. Johnson"
#   ],
#   "works_count": 132,
#   "cited_by_count": 1211,
#   "summary_stats": {
#     "2yr_mean_citedness": 5.0,
#     "h_index": 21,
#     "i10_index": 31
#   },
#   "ids": {
#     "openalex": "https://openalex.org/A5079865836",
#     "orcid": "https://orcid.org/0000-0001-5041-5018"
#   },
#   "affiliations": [
#     {
#       "institution": {
#         "id": "https://openalex.org/I102134673",
#         "ror": "https://ror.org/05ynxx418",
#         "display_name": "Link\u00f6ping University",
#         "country_code": "SE",
#         "type": "funder",
#         "lineage": [
#           "https://openalex.org/I102134673"
#         ]
#       },
#       "years": [
#         2025,
#         2024,
#         2023,
#         2022,
#         2021,
#         2019,
#         2018,
#         2017,
#         2016,
#         2015
#       ]
#     },
#     {
#       "institution": {
#         "id": "https://openalex.org/I86501945",
#         "ror": "https://ror.org/01sbq1a82",
#         "display_name": "University of Delaware",
#         "country_code": "US",
#         "type": "funder",
#         "lineage": [
#           "https://openalex.org/I86501945"
#         ]
#       },
#       "years": [
#         2023
#       ]
#     },
#     {
#       "institution": {
#         "id": "https://openalex.org/I16820183",
#         "ror": "https://ror.org/02ys5x139",
#         "display_name": "Illinois College",
#         "country_code": "US",
#         "type": "education",
#         "lineage": [
#           "https://openalex.org/I16820183"
#         ]
#       },
#       "years": [
#         2016
#       ]
#     },
#     {
#       "institution": {
#         "id": "https://openalex.org/I881427289",
#         "ror": "https://ror.org/01tm6cn81",
#         "display_name": "University of Gothenburg",
#         "country_code": "SE",
#         "type": "funder",
#         "lineage": [
#           "https://openalex.org/I881427289"
#         ]
#       },
#       "years": [
#         2011,
#         2010,
#         2009,
#         2008
#       ]
#     },
#     {
#       "institution": {
#         "id": "https://openalex.org/I185977053",
#         "ror": "https://ror.org/03gc71b86",
#         "display_name": "Swedish Collegium for Advanced Study",
#         "country_code": "SE",
#         "type": "funder",
#         "lineage": [
#           "https://openalex.org/I185977053"
#         ]
#       },
#       "years": [
#         2011
#       ]
#     },
#     {
#       "institution": {
#         "id": "https://openalex.org/I39422238",
#         "ror": "https://ror.org/02mpq6x41",
#         "display_name": "University of Illinois Chicago",
#         "country_code": "US",
#         "type": "funder",
#         "lineage": [
#           "https://openalex.org/I39422238"
#         ]
#       },
#       "years": [
#         2004,
#         2000
#       ]
#     },
#     {
#       "institution": {
#         "id": "https://openalex.org/I157725225",
#         "ror": "https://ror.org/047426m28",
#         "display_name": "University of Illinois Urbana-Champaign",
#         "country_code": "US",
#         "type": "funder",
#         "lineage": [
#           "https://openalex.org/I157725225"
#         ]
#       },
#       "years": [
#         2004
#       ]
#     },
#     {
#       "institution": {
#         "id": "https://openalex.org/I185443292",
#         "ror": "https://ror.org/01070mq45",
#         "display_name": "Wayne State University",
#         "country_code": "US",
#         "type": "funder",
#         "lineage": [
#           "https://openalex.org/I185443292"
#         ]
#       },
#       "years": [
#         2003
#       ]
#     },
#     {
#       "institution": {
#         "id": "https://openalex.org/I141649380",
#         "ror": "https://ror.org/04j198w64",
#         "display_name": "Western Michigan University",
#         "country_code": "US",
#         "type": "funder",
#         "lineage": [
#           "https://openalex.org/I141649380"
#         ]
#       },
#       "years": [
#         2001,
#         1989
#       ]
#     },
#     {
#       "institution": {
#         "id": "https://openalex.org/I58956616",
#         "ror": "https://ror.org/051fd9666",
#         "display_name": "Case Western Reserve University",
#         "country_code": "US",
#         "type": "funder",
#         "lineage": [
#           "https://openalex.org/I58956616"
#         ]
#       },
#       "years": [
#         1999,
#         1998,
#         1997,
#         1996,
#         1995,
#         1994,
#         1992
#       ]
#     }
#   ],
#   "last_known_institutions": [
#     {
#       "id": "https://openalex.org/I102134673",
#       "ror": "https://ror.org/05ynxx418",
#       "display_name": "Link\u00f6ping University",
#       "country_code": "SE",
#       "type": "funder",
#       "lineage": [
#         "https://openalex.org/I102134673"
#       ]
#     }
#   ],
#   "topics": [
#     {
#       "id": "https://openalex.org/T11464",
#       "display_name": "Homelessness and Social Issues",
#       "count": 12,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3600",
#         "display_name": "General Health Professions"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/36",
#         "display_name": "Health Professions"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11028",
#       "display_name": "Social Work Education and Practice",
#       "count": 10,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3321",
#         "display_name": "Public Administration"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T13332",
#       "display_name": "Historical Studies on Reproduction, Gender, Health, and Societal Changes",
#       "count": 9,
#       "subfield": {
#         "id": "https://openalex.org/subfields/1202",
#         "display_name": "History"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/12",
#         "display_name": "Arts and Humanities"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11497",
#       "display_name": "Interprofessional Education and Collaboration",
#       "count": 8,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3600",
#         "display_name": "General Health Professions"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/36",
#         "display_name": "Health Professions"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11639",
#       "display_name": "Mental Health and Patient Involvement",
#       "count": 7,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3600",
#         "display_name": "General Health Professions"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/36",
#         "display_name": "Health Professions"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11238",
#       "display_name": "Simulation-Based Education in Healthcare",
#       "count": 7,
#       "subfield": {
#         "id": "https://openalex.org/subfields/2737",
#         "display_name": "Physiology"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/27",
#         "display_name": "Medicine"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T12021",
#       "display_name": "Social and Educational Sciences",
#       "count": 7,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3304",
#         "display_name": "Education"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11645",
#       "display_name": "Urban, Neighborhood, and Segregation Studies",
#       "count": 6,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3312",
#         "display_name": "Sociology and Political Science"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T10459",
#       "display_name": "Sexual function and dysfunction studies",
#       "count": 5,
#       "subfield": {
#         "id": "https://openalex.org/subfields/2738",
#         "display_name": "Psychiatry and Mental health"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/27",
#         "display_name": "Medicine"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11817",
#       "display_name": "Housing, Finance, and Neoliberalism",
#       "count": 4,
#       "subfield": {
#         "id": "https://openalex.org/subfields/2003",
#         "display_name": "Finance"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/20",
#         "display_name": "Economics, Econometrics and Finance"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T13417",
#       "display_name": "Biomedical Ethics and Regulation",
#       "count": 4,
#       "subfield": {
#         "id": "https://openalex.org/subfields/2737",
#         "display_name": "Physiology"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/27",
#         "display_name": "Medicine"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T12335",
#       "display_name": "Sexuality, Behavior, and Technology",
#       "count": 4,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3203",
#         "display_name": "Clinical Psychology"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/32",
#         "display_name": "Psychology"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T10738",
#       "display_name": "Posthumanist Ethics and Activism",
#       "count": 4,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3316",
#         "display_name": "Cultural Studies"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11999",
#       "display_name": "Empathy and Medical Education",
#       "count": 4,
#       "subfield": {
#         "id": "https://openalex.org/subfields/2738",
#         "display_name": "Psychiatry and Mental health"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/27",
#         "display_name": "Medicine"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T10916",
#       "display_name": "Surgical Simulation and Training",
#       "count": 4,
#       "subfield": {
#         "id": "https://openalex.org/subfields/2746",
#         "display_name": "Surgery"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/27",
#         "display_name": "Medicine"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T10254",
#       "display_name": "Innovations in Medical Education",
#       "count": 4,
#       "subfield": {
#         "id": "https://openalex.org/subfields/2739",
#         "display_name": "Public Health, Environmental and Occupational Health"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/27",
#         "display_name": "Medicine"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T12666",
#       "display_name": "Historical Psychiatry and Medical Practices",
#       "count": 4,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3203",
#         "display_name": "Clinical Psychology"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/32",
#         "display_name": "Psychology"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11806",
#       "display_name": "Service-Learning and Community Engagement",
#       "count": 4,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3304",
#         "display_name": "Education"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11197",
#       "display_name": "Digital Games and Media",
#       "count": 3,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3312",
#         "display_name": "Sociology and Political Science"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T14238",
#       "display_name": "Historical Gender and Feminism Studies",
#       "count": 3,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3312",
#         "display_name": "Sociology and Political Science"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11120",
#       "display_name": "Nonprofit Sector and Volunteering",
#       "count": 3,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3312",
#         "display_name": "Sociology and Political Science"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T10557",
#       "display_name": "Social Media and Politics",
#       "count": 3,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3315",
#         "display_name": "Communication"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T10883",
#       "display_name": "Ethics and Social Impacts of AI",
#       "count": 3,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3311",
#         "display_name": "Safety Research"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11792",
#       "display_name": "Pharmaceutical Economics and Policy",
#       "count": 3,
#       "subfield": {
#         "id": "https://openalex.org/subfields/2002",
#         "display_name": "Economics and Econometrics"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/20",
#         "display_name": "Economics, Econometrics and Finance"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T12749",
#       "display_name": "Race, Genetics, and Society",
#       "count": 3,
#       "subfield": {
#         "id": "https://openalex.org/subfields/1311",
#         "display_name": "Genetics"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/13",
#         "display_name": "Biochemistry, Genetics and Molecular Biology"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/1",
#         "display_name": "Life Sciences"
#       }
#     }
#   ],
#   "topic_share": [
#     {
#       "id": "https://openalex.org/T10738",
#       "display_name": "Posthumanist Ethics and Activism",
#       "value": 0.0002069,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3316",
#         "display_name": "Cultural Studies"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T12320",
#       "display_name": "Feminist Epistemology and Gender Studies",
#       "value": 0.0001804,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3312",
#         "display_name": "Sociology and Political Science"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T13368",
#       "display_name": "University Challenges and Reforms",
#       "value": 0.0001172,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3304",
#         "display_name": "Education"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11238",
#       "display_name": "Simulation-Based Education in Healthcare",
#       "value": 0.000113,
#       "subfield": {
#         "id": "https://openalex.org/subfields/2737",
#         "display_name": "Physiology"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/27",
#         "display_name": "Medicine"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T13585",
#       "display_name": "Technostress in Professional Settings",
#       "value": 0.0001061,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3207",
#         "display_name": "Social Psychology"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/32",
#         "display_name": "Psychology"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11028",
#       "display_name": "Social Work Education and Practice",
#       "value": 9.73e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3321",
#         "display_name": "Public Administration"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T13332",
#       "display_name": "Historical Studies on Reproduction, Gender, Health, and Societal Changes",
#       "value": 9.24e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/1202",
#         "display_name": "History"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/12",
#         "display_name": "Arts and Humanities"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T12749",
#       "display_name": "Race, Genetics, and Society",
#       "value": 9.21e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/1311",
#         "display_name": "Genetics"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/13",
#         "display_name": "Biochemistry, Genetics and Molecular Biology"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/1",
#         "display_name": "Life Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T14074",
#       "display_name": "Persona Design and Applications",
#       "value": 7.51e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/1709",
#         "display_name": "Human-Computer Interaction"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/17",
#         "display_name": "Computer Science"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/3",
#         "display_name": "Physical Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11639",
#       "display_name": "Mental Health and Patient Involvement",
#       "value": 7.44e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3600",
#         "display_name": "General Health Professions"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/36",
#         "display_name": "Health Professions"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T13720",
#       "display_name": "Benford\u2019s Law and Fraud Detection",
#       "value": 7.03e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/2613",
#         "display_name": "Statistics and Probability"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/26",
#         "display_name": "Mathematics"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/3",
#         "display_name": "Physical Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T13927",
#       "display_name": "Cyberloafing and Workplace Behavior",
#       "value": 6.63e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3317",
#         "display_name": "Demography"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11497",
#       "display_name": "Interprofessional Education and Collaboration",
#       "value": 6.09e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3600",
#         "display_name": "General Health Professions"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/36",
#         "display_name": "Health Professions"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T12666",
#       "display_name": "Historical Psychiatry and Medical Practices",
#       "value": 5.6e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3203",
#         "display_name": "Clinical Psychology"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/32",
#         "display_name": "Psychology"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T10709",
#       "display_name": "Social Robot Interaction and HRI",
#       "value": 4.9e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3207",
#         "display_name": "Social Psychology"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/32",
#         "display_name": "Psychology"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11645",
#       "display_name": "Urban, Neighborhood, and Segregation Studies",
#       "value": 4.84e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3312",
#         "display_name": "Sociology and Political Science"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T10459",
#       "display_name": "Sexual function and dysfunction studies",
#       "value": 4.84e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/2738",
#         "display_name": "Psychiatry and Mental health"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/27",
#         "display_name": "Medicine"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11464",
#       "display_name": "Homelessness and Social Issues",
#       "value": 4.72e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3600",
#         "display_name": "General Health Professions"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/36",
#         "display_name": "Health Professions"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T10883",
#       "display_name": "Ethics and Social Impacts of AI",
#       "value": 4.71e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3311",
#         "display_name": "Safety Research"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11806",
#       "display_name": "Service-Learning and Community Engagement",
#       "value": 4.71e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3304",
#         "display_name": "Education"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T13700",
#       "display_name": "Gender Studies and Social Issues",
#       "value": 4.59e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3318",
#         "display_name": "Gender Studies"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T10916",
#       "display_name": "Surgical Simulation and Training",
#       "value": 4.34e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/2746",
#         "display_name": "Surgery"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/27",
#         "display_name": "Medicine"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/4",
#         "display_name": "Health Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T12978",
#       "display_name": "Innovative Teaching Methodologies in Social Sciences",
#       "value": 4.28e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3304",
#         "display_name": "Education"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11120",
#       "display_name": "Nonprofit Sector and Volunteering",
#       "value": 4.04e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/3312",
#         "display_name": "Sociology and Political Science"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/33",
#         "display_name": "Social Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T14148",
#       "display_name": "Kierkegaardian Philosophy and Influence",
#       "value": 3.88e-05,
#       "subfield": {
#         "id": "https://openalex.org/subfields/1211",
#         "display_name": "Philosophy"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/12",
#         "display_name": "Arts and Humanities"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     }
#   ],
#   "x_concepts": [
#     {
#       "id": "https://openalex.org/C144024400",
#       "wikidata": "https://www.wikidata.org/wiki/Q21201",
#       "display_name": "Sociology",
#       "level": 0,
#       "score": 54.5
#     },
#     {
#       "id": "https://openalex.org/C71924100",
#       "wikidata": "https://www.wikidata.org/wiki/Q11190",
#       "display_name": "Medicine",
#       "level": 0,
#       "score": 51.5
#     },
#     {
#       "id": "https://openalex.org/C15744967",
#       "wikidata": "https://www.wikidata.org/wiki/Q9418",
#       "display_name": "Psychology",
#       "level": 0,
#       "score": 50.8
#     },
#     {
#       "id": "https://openalex.org/C41008148",
#       "wikidata": "https://www.wikidata.org/wiki/Q21198",
#       "display_name": "Computer science",
#       "level": 0,
#       "score": 50.8
#     },
#     {
#       "id": "https://openalex.org/C17744445",
#       "wikidata": "https://www.wikidata.org/wiki/Q36442",
#       "display_name": "Political science",
#       "level": 0,
#       "score": 47.7
#     },
#     {
#       "id": "https://openalex.org/C199539241",
#       "wikidata": "https://www.wikidata.org/wiki/Q7748",
#       "display_name": "Law",
#       "level": 1,
#       "score": 43.2
#     },
#     {
#       "id": "https://openalex.org/C86803240",
#       "wikidata": "https://www.wikidata.org/wiki/Q420",
#       "display_name": "Biology",
#       "level": 0,
#       "score": 33.3
#     },
#     {
#       "id": "https://openalex.org/C162324750",
#       "wikidata": "https://www.wikidata.org/wiki/Q8134",
#       "display_name": "Economics",
#       "level": 0,
#       "score": 30.3
#     },
#     {
#       "id": "https://openalex.org/C127413603",
#       "wikidata": "https://www.wikidata.org/wiki/Q11023",
#       "display_name": "Engineering",
#       "level": 0,
#       "score": 27.3
#     },
#     {
#       "id": "https://openalex.org/C138885662",
#       "wikidata": "https://www.wikidata.org/wiki/Q5891",
#       "display_name": "Philosophy",
#       "level": 0,
#       "score": 27.3
#     },
#     {
#       "id": "https://openalex.org/C121332964",
#       "wikidata": "https://www.wikidata.org/wiki/Q413",
#       "display_name": "Physics",
#       "level": 0,
#       "score": 22.7
#     }
#   ],
#   "counts_by_year": [
#     {
#       "year": 2025,
#       "works_count": 3,
#       "cited_by_count": 33
#     },
#     {
#       "year": 2024,
#       "works_count": 2,
#       "cited_by_count": 80
#     },
#     {
#       "year": 2023,
#       "works_count": 7,
#       "cited_by_count": 78
#     },
#     {
#       "year": 2022,
#       "works_count": 1,
#       "cited_by_count": 44
#     },
#     {
#       "year": 2021,
#       "works_count": 7,
#       "cited_by_count": 52
#     },
#     {
#       "year": 2020,
#       "works_count": 3,
#       "cited_by_count": 56
#     },
#     {
#       "year": 2019,
#       "works_count": 12,
#       "cited_by_count": 59
#     },
#     {
#       "year": 2018,
#       "works_count": 3,
#       "cited_by_count": 41
#     },
#     {
#       "year": 2017,
#       "works_count": 6,
#       "cited_by_count": 57
#     },
#     {
#       "year": 2016,
#       "works_count": 13,
#       "cited_by_count": 69
#     },
#     {
#       "year": 2015,
#       "works_count": 1,
#       "cited_by_count": 54
#     },
#     {
#       "year": 2014,
#       "works_count": 1,
#       "cited_by_count": 38
#     },
#     {
#       "year": 2013,
#       "works_count": 2,
#       "cited_by_count": 62
#     },
#     {
#       "year": 2012,
#       "works_count": 6,
#       "cited_by_count": 69
#     }
#   ],
#   "works_api_url": "https://api.openalex.org/works?filter=author.id:A5079865836",
#   "updated_date": "2025-06-16T22:26:13.308664",
#   "created_date": "2023-07-21"
# }

# %%
# what keys did we retrieve from openAlex?
print(first_entry.keys())
# Out:
# dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])

# %%
# now I'll do it for all ORCIDs I have
orcid_df_clean["retrieved_author_data"] = orcid_df_clean.apply(get_author_id, axis=1)
orcid_df_clean
# Out:
# /var/folders/4n/x6xrnlyj6nngzc77qzc7h4f40000gn/T/ipykernel_15318/3327022916.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orcid_df_clean["retrieved_author_data"] = orcid_df_clean.apply(get_author_id, axis=1)
#              ResponseId                               DE13_2_1  \
# 6     R_2DUIfkur5fbOgZo                    0000-0001-5041-5018
# 12    R_46yreKgPLBawn3H                    0000-0002-2763-0921
# 13    R_2ZTGtufLu3KUHW9                       0000000181844747
# 15    R_1gzm4gKhyxKNWBW  http://orcid.org/0000-0002-2475-1496
# 16    R_3w5HE5P6WKA3ErS  https://orcid.org/0000-0002-8785-8063
# ...                 ...                                    ...
# 3218  R_216eipKa8MqFn3z  https://orcid.org/0000-0002-6409-2632
# 3219  R_8FlyCLCDJMPasD4  https://orcid.org/0000-0002-6873-2967
# 3228  R_2X0fTWPBw20QquW                    0000-0003-1528-8185
# 3232  R_2WwaSOfdPYRwAwN                    0000-0003-1891-7522
# 3234  R_2iFjsLGZX3qEgu0  https://orcid.org/0000-0002-9203-7550
#
#                              orcid_standard  \
# 6     https://orcid.org/0000-0001-5041-5018
# 12    https://orcid.org/0000-0002-2763-0921
# 13    https://orcid.org/0000-0001-8184-4747
# 15    https://orcid.org/0000-0002-2475-1496
# 16    https://orcid.org/0000-0002-8785-8063
# ...                                     ...
# 3218  https://orcid.org/0000-0002-6409-2632
# 3219  https://orcid.org/0000-0002-6873-2967
# 3228  https://orcid.org/0000-0003-1528-8185
# 3232  https://orcid.org/0000-0003-1891-7522
# 3234  https://orcid.org/0000-0002-9203-7550
#
#                                   retrieved_author_data
# 6     {'id': 'https://openalex.org/A5079865836', 'or...
# 12    {'id': 'https://openalex.org/A5061820165', 'or...
# 13    {'id': 'https://openalex.org/A5065296382', 'or...
# 15    {'id': 'https://openalex.org/A5087740005', 'or...
# 16    {'id': 'https://openalex.org/A5043649135', 'or...
# ...                                                 ...
# 3218  {'id': 'https://openalex.org/A5044882262', 'or...
# 3219  {'id': 'https://openalex.org/A5070800805', 'or...
# 3228  {'id': 'https://openalex.org/A5013763672', 'or...
# 3232  {'id': 'https://openalex.org/A5076688390', 'or...
# 3234  {'id': 'https://openalex.org/A5083904390', 'or...
#
# [1225 rows x 4 columns]

# %%
num_missing = orcid_df_clean['retrieved_author_data'].isna().sum()
print(f"{num_missing} rows in 'retrieved_author_data' are NaN or empty/null")

missing_df = orcid_df_clean[orcid_df_clean['retrieved_author_data'].isna()]
missing_df
# Out:
# 30 rows in 'retrieved_author_data' are NaN or empty/null
#              ResponseId                                           DE13_2_1  \
# 28    R_5EaunHkYX129nRh                                0009-0009-4939-4939
# 77    R_8hfnTd8GVGqt0ZF                                0000-0002-3940-7292
# 112   R_27eCdCht7JBsF9M              https://orcid.org/0000-0003-2545-6314
# 250   R_2GLscYxxbUYtxcd                                0000-0002-1834-400X
# 370   R_8cqDPLMMPBd3mCq  https://orcid.org/my-orcid?orcid=0000-0001-908...
# 450   R_8S97TG6p6Cpdlff                                0000-0003-0060-6240
# 546   R_8kV5gXUj974j5ZL              https://orcid.org/0000-0003-2135-0539
# 586   R_21aXrM6Up0RX58B                                0000-0003-1327-8231
# 811   R_24Lqox12FZt7vMZ                                0000-0001-5456-992X
# 1115  R_2Bq1COoYdgw7JZf                                0000-0002-8912-2615
# 1182  R_8JIM5YfOREkd3iv              https://orcid.org/0000-0001-8812-8639
# 1203  R_2u9L7luULUgDAXL               http://orcid.org/0000-0002-0082-7505
# 1270  R_8fKf6bpayRBZHUQ                                0000-0002-4064-7349
# 1313  R_4KPKQt0JrYbxan9                                0000-0003-1621-3257
# 1469  R_8pwZUrb1dkNlyKZ                                0000-0001-8986-5366
# 1487  R_80ixPIm9xckukMU                      orcid.org/0000-0001-9004-7029
# 1788  R_2bK63IURkDAifRZ              https://orcid.org/0000-0002-2951-9119
# 1811  R_4hmDfQ22rt7YdHn             https://orcid.org/0000-0002-3641-995X)
# 1838  R_2sU2qba3ZYbTAlA              https://orcid.org/0000-0002-8130-617X
# 2123  R_2pKn8NqXJOCHeQV              https://orcid.org/0000-0003-1823-5505
# 2211  R_2oZnLoD7WQhdBwq              https://orcid.org/0000-0003-3715-8592
# 2274  R_2FUWMb9d7BXfcqZ                                0000-0002-3359-7136
# 2474  R_21n7iiSqjbgtJL8                                0000-0001-9250-000X
# 2645  R_2rE76LtFgh5wAOR              https://orcid.org/0000-0002-7563-6228
# 2727  R_2xwG277L2Ytu2Sl                                0000-0002-9333-5859
# 2800  R_8b7gCYYOonkEKfn              https://orcid.org/0000-0003-1185-9876
# 2808  R_2Phm4GqIrtqeuyD              https://orcid.org/0000-0003-3045-5359
# 2957  R_8lFSACfG0dsFOhY                                0000-0002-2475-1760
# 2999  R_8Rr1UlSgD29SJJN              https://orcid.org/0000-0002-4860-4853
# 3204  R_8CjfO9eKNEDqgWE                                0000-0002-5992-4291
#
#                              orcid_standard retrieved_author_data
# 28    https://orcid.org/0009-0009-4939-4939                  None
# 77    https://orcid.org/0000-0002-3940-7292                  None
# 112   https://orcid.org/0000-0003-2545-6314                  None
# 250   https://orcid.org/0000-0002-1834-400X                  None
# 370   https://orcid.org/0000-0001-9081-6780                  None
# 450   https://orcid.org/0000-0003-0060-6240                  None
# 546   https://orcid.org/0000-0003-2135-0539                  None
# 586   https://orcid.org/0000-0003-1327-8231                  None
# 811   https://orcid.org/0000-0001-5456-992X                  None
# 1115  https://orcid.org/0000-0002-8912-2615                  None
# 1182  https://orcid.org/0000-0001-8812-8639                  None
# 1203  https://orcid.org/0000-0002-0082-7505                  None
# 1270  https://orcid.org/0000-0002-4064-7349                  None
# 1313  https://orcid.org/0000-0003-1621-3257                  None
# 1469  https://orcid.org/0000-0001-8986-5366                  None
# 1487  https://orcid.org/0000-0001-9004-7029                  None
# 1788  https://orcid.org/0000-0002-2951-9119                  None
# 1811  https://orcid.org/0000-0002-3641-995X                  None
# 1838  https://orcid.org/0000-0002-8130-617X                  None
# 2123  https://orcid.org/0000-0003-1823-5505                  None
# 2211  https://orcid.org/0000-0003-3715-8592                  None
# 2274  https://orcid.org/0000-0002-3359-7136                  None
# 2474  https://orcid.org/0000-0001-9250-000X                  None
# 2645  https://orcid.org/0000-0002-7563-6228                  None
# 2727  https://orcid.org/0000-0002-9333-5859                  None
# 2800  https://orcid.org/0000-0003-1185-9876                  None
# 2808  https://orcid.org/0000-0003-3045-5359                  None
# 2957  https://orcid.org/0000-0002-2475-1760                  None
# 2999  https://orcid.org/0000-0002-4860-4853                  None
# 3204  https://orcid.org/0000-0002-5992-4291                  None

# %% [markdown]
# I tried to restrieve from 1225 researchers  Orcids data from Open Alex. 30 Orcids from those 1225 are not found via the Open Alex API.
# This means I have 1195 from OpenAlex found by provided Orcids.

# %%
orcid_df_clean_no_missing = orcid_df_clean[~orcid_df_clean['ResponseId'].isin(missing_df['ResponseId'])]
orcid_df_clean_no_missing.reset_index(drop=True, inplace=True)
len(orcid_df_clean_no_missing)
# Out:
# 1195

# %%
orcid_df_clean_no_missing.to_pickle("firstScrape_on_oA_by_orcids.pkl")

# %%
orcid_df = pd.read_pickle("firstScrape_on_oA_by_orcids.pkl")
orcid_df.head()
# Out:
#           ResponseId                               DE13_2_1  \
# 0  R_2DUIfkur5fbOgZo                    0000-0001-5041-5018
# 1  R_46yreKgPLBawn3H                    0000-0002-2763-0921
# 2  R_2ZTGtufLu3KUHW9                       0000000181844747
# 3  R_1gzm4gKhyxKNWBW  http://orcid.org/0000-0002-2475-1496
# 4  R_3w5HE5P6WKA3ErS  https://orcid.org/0000-0002-8785-8063
#
#                           orcid_standard  \
# 0  https://orcid.org/0000-0001-5041-5018
# 1  https://orcid.org/0000-0002-2763-0921
# 2  https://orcid.org/0000-0001-8184-4747
# 3  https://orcid.org/0000-0002-2475-1496
# 4  https://orcid.org/0000-0002-8785-8063
#
#                                retrieved_author_data
# 0  {'id': 'https://openalex.org/A5079865836', 'or...
# 1  {'id': 'https://openalex.org/A5061820165', 'or...
# 2  {'id': 'https://openalex.org/A5065296382', 'or...
# 3  {'id': 'https://openalex.org/A5087740005', 'or...
# 4  {'id': 'https://openalex.org/A5043649135', 'or...

# %%
print(orcid_df['orcid_standard'].apply(type).value_counts())
print(orcid_df['orcid_standard'].head())
# Out:
# orcid_standard
# <class 'str'>    1195
# Name: count, dtype: int64
# 0    https://orcid.org/0000-0001-5041-5018
# 1    https://orcid.org/0000-0002-2763-0921
# 2    https://orcid.org/0000-0001-8184-4747
# 3    https://orcid.org/0000-0002-2475-1496
# 4    https://orcid.org/0000-0002-8785-8063
# Name: orcid_standard, dtype: object

# %%
missing_df.to_pickle("not_found_orcids_on_oA.pkl")

# %%
df_orcid = orcid_df.copy()
df_orcid_normal = orcid_df['retrieved_author_data'].apply(pd.Series)
df_final = pd.concat([df_orcid[['ResponseId']], df_orcid_normal], axis=1)
df_final.head()
# Out:
#           ResponseId                                id  \
# 0  R_2DUIfkur5fbOgZo  https://openalex.org/A5079865836
# 1  R_46yreKgPLBawn3H  https://openalex.org/A5061820165
# 2  R_2ZTGtufLu3KUHW9  https://openalex.org/A5065296382
# 3  R_1gzm4gKhyxKNWBW  https://openalex.org/A5087740005
# 4  R_3w5HE5P6WKA3ErS  https://openalex.org/A5043649135
#
#                                    orcid        display_name  \
# 0  https://orcid.org/0000-0001-5041-5018      Ericka Johnson
# 1  https://orcid.org/0000-0002-2763-0921      John A. Timney
# 2  https://orcid.org/0000-0001-8184-4747  Özge Karaosmanoğlu
# 3  https://orcid.org/0000-0002-2475-1496  Viktoriia Strilets
# 4  https://orcid.org/0000-0002-8785-8063         Thomas Louf
#
#                            display_name_alternatives  works_count  \
# 0  [Alice K. Johnson, Ericka Johnson, Austin Jero...          132
# 1  [John Timney, John Anthony Timney, John A. Tim...           55
# 2           [Ozge Karaosmanoglu, Özge Karaosmanoğlu]           30
# 3  [V. Y. Strilets, Viktoriia Strilets, Valerii S...           11
# 4                                      [Thomas Louf]           14
#
#    cited_by_count                                      summary_stats  \
# 0            1211  {'2yr_mean_citedness': 5.0, 'h_index': 21, 'i1...
# 1             813  {'2yr_mean_citedness': 0.5, 'h_index': 14, 'i1...
# 2             224  {'2yr_mean_citedness': 3.75, 'h_index': 3, 'i1...
# 3              24  {'2yr_mean_citedness': 1.0, 'h_index': 3, 'i10...
# 4              24  {'2yr_mean_citedness': 0.6666666666666666, 'h_...
#
#                                                  ids  \
# 0  {'openalex': 'https://openalex.org/A5079865836...
# 1  {'openalex': 'https://openalex.org/A5061820165...
# 2  {'openalex': 'https://openalex.org/A5065296382...
# 3  {'openalex': 'https://openalex.org/A5087740005...
# 4  {'openalex': 'https://openalex.org/A5043649135...
#
#                                         affiliations  \
# 0  [{'institution': {'id': 'https://openalex.org/...
# 1  [{'institution': {'id': 'https://openalex.org/...
# 2  [{'institution': {'id': 'https://openalex.org/...
# 3  [{'institution': {'id': 'https://openalex.org/...
# 4  [{'institution': {'id': 'https://openalex.org/...
#
#                              last_known_institutions  \
# 0  [{'id': 'https://openalex.org/I102134673', 'ro...
# 1  [{'id': 'https://openalex.org/I91136226', 'ror...
# 2  [{'id': 'https://openalex.org/I322491407', 'ro...
# 3  [{'id': 'https://openalex.org/I8765205', 'ror'...
# 4  [{'id': 'https://openalex.org/I4210095952', 'r...
#
#                                               topics  \
# 0  [{'id': 'https://openalex.org/T11464', 'displa...
# 1  [{'id': 'https://openalex.org/T11746', 'displa...
# 2  [{'id': 'https://openalex.org/T10390', 'displa...
# 3  [{'id': 'https://openalex.org/T11396', 'displa...
# 4  [{'id': 'https://openalex.org/T12090', 'displa...
#
#                                          topic_share  \
# 0  [{'id': 'https://openalex.org/T10738', 'displa...
# 1  [{'id': 'https://openalex.org/T13192', 'displa...
# 2  [{'id': 'https://openalex.org/T10390', 'displa...
# 3  [{'id': 'https://openalex.org/T13608', 'displa...
# 4  [{'id': 'https://openalex.org/T12380', 'displa...
#
#                                           x_concepts  \
# 0  [{'id': 'https://openalex.org/C144024400', 'wi...
# 1  [{'id': 'https://openalex.org/C185592680', 'wi...
# 2  [{'id': 'https://openalex.org/C54355233', 'wik...
# 3  [{'id': 'https://openalex.org/C41008148', 'wik...
# 4  [{'id': 'https://openalex.org/C41008148', 'wik...
#
#                                       counts_by_year  \
# 0  [{'year': 2025, 'works_count': 3, 'cited_by_co...
# 1  [{'year': 2025, 'works_count': 0, 'cited_by_co...
# 2  [{'year': 2025, 'works_count': 7, 'cited_by_co...
# 3  [{'year': 2025, 'works_count': 1, 'cited_by_co...
# 4  [{'year': 2025, 'works_count': 1, 'cited_by_co...
#
#                                        works_api_url  \
# 0  https://api.openalex.org/works?filter=author.i...
# 1  https://api.openalex.org/works?filter=author.i...
# 2  https://api.openalex.org/works?filter=author.i...
# 3  https://api.openalex.org/works?filter=author.i...
# 4  https://api.openalex.org/works?filter=author.i...
#
#                  updated_date created_date
# 0  2025-06-16T22:26:13.308664   2023-07-21
# 1  2025-06-22T12:36:14.235761   2023-07-21
# 2  2025-06-26T05:47:41.692081   2023-07-21
# 3  2025-06-23T02:41:38.495338   2023-07-21
# 4  2025-06-17T20:11:09.678815   2023-07-21

# %%
df_final.columns
# Out:
# Index(['ResponseId', 'id', 'orcid', 'display_name',
#        'display_name_alternatives', 'works_count', 'cited_by_count',
#        'summary_stats', 'ids', 'affiliations', 'last_known_institutions',
#        'topics', 'topic_share', 'x_concepts', 'counts_by_year',
#        'works_api_url', 'updated_date', 'created_date'],
#       dtype='object')

# %%
# what is the content in col counts_by_year?
first_entry = df_final['counts_by_year'].iloc[0]
print(json.dumps(first_entry, indent=2))
# Out:
# [
#   {
#     "year": 2025,
#     "works_count": 3,
#     "cited_by_count": 33
#   },
#   {
#     "year": 2024,
#     "works_count": 2,
#     "cited_by_count": 80
#   },
#   {
#     "year": 2023,
#     "works_count": 7,
#     "cited_by_count": 78
#   },
#   {
#     "year": 2022,
#     "works_count": 1,
#     "cited_by_count": 44
#   },
#   {
#     "year": 2021,
#     "works_count": 7,
#     "cited_by_count": 52
#   },
#   {
#     "year": 2020,
#     "works_count": 3,
#     "cited_by_count": 56
#   },
#   {
#     "year": 2019,
#     "works_count": 12,
#     "cited_by_count": 59
#   },
#   {
#     "year": 2018,
#     "works_count": 3,
#     "cited_by_count": 41
#   },
#   {
#     "year": 2017,
#     "works_count": 6,
#     "cited_by_count": 57
#   },
#   {
#     "year": 2016,
#     "works_count": 13,
#     "cited_by_count": 69
#   },
#   {
#     "year": 2015,
#     "works_count": 1,
#     "cited_by_count": 54
#   },
#   {
#     "year": 2014,
#     "works_count": 1,
#     "cited_by_count": 38
#   },
#   {
#     "year": 2013,
#     "works_count": 2,
#     "cited_by_count": 62
#   },
#   {
#     "year": 2012,
#     "works_count": 6,
#     "cited_by_count": 69
#   }
# ]

# %% [markdown]
# works_count = the number of works an author has created
# works_api_url = list of all this author's works
# summary_stats = citation metrics for this author
# last_known_institutions = author's last known institutional affiliations (all authors Works sorted by pub date, most recent one selected)
# cited_by_count = total number works that cite a work of an author
#
# so this means for the first entry you see above that in 2025, the author published 3 works, and those 3 works have been cited 33 times in total up to the current moment (not just in 2025).
#
#
# x_concepts = concepts most frequently applied to works created by this author

# %% [markdown]
# counts_by_year gives information abou how many works this author published, and how many times they got cited binned by year. https://docs.openalex.org/api-entities/authors/author-object.

# %%
# what is the content in col topics/ topic_share? And all the other columns?
first_entry = df_final['topics'].iloc[0]
print(json.dumps(first_entry, indent=2))
# Out:
# [
#   {
#     "id": "https://openalex.org/T11464",
#     "display_name": "Homelessness and Social Issues",
#     "count": 12,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3600",
#       "display_name": "General Health Professions"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/36",
#       "display_name": "Health Professions"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11028",
#     "display_name": "Social Work Education and Practice",
#     "count": 10,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3321",
#       "display_name": "Public Administration"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T13332",
#     "display_name": "Historical Studies on Reproduction, Gender, Health, and Societal Changes",
#     "count": 9,
#     "subfield": {
#       "id": "https://openalex.org/subfields/1202",
#       "display_name": "History"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/12",
#       "display_name": "Arts and Humanities"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11497",
#     "display_name": "Interprofessional Education and Collaboration",
#     "count": 8,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3600",
#       "display_name": "General Health Professions"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/36",
#       "display_name": "Health Professions"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11639",
#     "display_name": "Mental Health and Patient Involvement",
#     "count": 7,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3600",
#       "display_name": "General Health Professions"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/36",
#       "display_name": "Health Professions"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11238",
#     "display_name": "Simulation-Based Education in Healthcare",
#     "count": 7,
#     "subfield": {
#       "id": "https://openalex.org/subfields/2737",
#       "display_name": "Physiology"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/27",
#       "display_name": "Medicine"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T12021",
#     "display_name": "Social and Educational Sciences",
#     "count": 7,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3304",
#       "display_name": "Education"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11645",
#     "display_name": "Urban, Neighborhood, and Segregation Studies",
#     "count": 6,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3312",
#       "display_name": "Sociology and Political Science"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T10459",
#     "display_name": "Sexual function and dysfunction studies",
#     "count": 5,
#     "subfield": {
#       "id": "https://openalex.org/subfields/2738",
#       "display_name": "Psychiatry and Mental health"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/27",
#       "display_name": "Medicine"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11817",
#     "display_name": "Housing, Finance, and Neoliberalism",
#     "count": 4,
#     "subfield": {
#       "id": "https://openalex.org/subfields/2003",
#       "display_name": "Finance"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/20",
#       "display_name": "Economics, Econometrics and Finance"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T13417",
#     "display_name": "Biomedical Ethics and Regulation",
#     "count": 4,
#     "subfield": {
#       "id": "https://openalex.org/subfields/2737",
#       "display_name": "Physiology"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/27",
#       "display_name": "Medicine"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T12335",
#     "display_name": "Sexuality, Behavior, and Technology",
#     "count": 4,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3203",
#       "display_name": "Clinical Psychology"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/32",
#       "display_name": "Psychology"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T10738",
#     "display_name": "Posthumanist Ethics and Activism",
#     "count": 4,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3316",
#       "display_name": "Cultural Studies"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11999",
#     "display_name": "Empathy and Medical Education",
#     "count": 4,
#     "subfield": {
#       "id": "https://openalex.org/subfields/2738",
#       "display_name": "Psychiatry and Mental health"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/27",
#       "display_name": "Medicine"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T10916",
#     "display_name": "Surgical Simulation and Training",
#     "count": 4,
#     "subfield": {
#       "id": "https://openalex.org/subfields/2746",
#       "display_name": "Surgery"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/27",
#       "display_name": "Medicine"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T10254",
#     "display_name": "Innovations in Medical Education",
#     "count": 4,
#     "subfield": {
#       "id": "https://openalex.org/subfields/2739",
#       "display_name": "Public Health, Environmental and Occupational Health"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/27",
#       "display_name": "Medicine"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T12666",
#     "display_name": "Historical Psychiatry and Medical Practices",
#     "count": 4,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3203",
#       "display_name": "Clinical Psychology"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/32",
#       "display_name": "Psychology"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11806",
#     "display_name": "Service-Learning and Community Engagement",
#     "count": 4,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3304",
#       "display_name": "Education"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11197",
#     "display_name": "Digital Games and Media",
#     "count": 3,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3312",
#       "display_name": "Sociology and Political Science"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T14238",
#     "display_name": "Historical Gender and Feminism Studies",
#     "count": 3,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3312",
#       "display_name": "Sociology and Political Science"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11120",
#     "display_name": "Nonprofit Sector and Volunteering",
#     "count": 3,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3312",
#       "display_name": "Sociology and Political Science"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T10557",
#     "display_name": "Social Media and Politics",
#     "count": 3,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3315",
#       "display_name": "Communication"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T10883",
#     "display_name": "Ethics and Social Impacts of AI",
#     "count": 3,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3311",
#       "display_name": "Safety Research"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11792",
#     "display_name": "Pharmaceutical Economics and Policy",
#     "count": 3,
#     "subfield": {
#       "id": "https://openalex.org/subfields/2002",
#       "display_name": "Economics and Econometrics"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/20",
#       "display_name": "Economics, Econometrics and Finance"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T12749",
#     "display_name": "Race, Genetics, and Society",
#     "count": 3,
#     "subfield": {
#       "id": "https://openalex.org/subfields/1311",
#       "display_name": "Genetics"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/13",
#       "display_name": "Biochemistry, Genetics and Molecular Biology"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/1",
#       "display_name": "Life Sciences"
#     }
#   }
# ]

# %%
# what is the content in col topics/ topic_share? And all the other columns?
first_entry = df_final['topic_share'].iloc[0]
print(json.dumps(first_entry, indent=2))
# Out:
# [
#   {
#     "id": "https://openalex.org/T10738",
#     "display_name": "Posthumanist Ethics and Activism",
#     "value": 0.0002069,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3316",
#       "display_name": "Cultural Studies"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T12320",
#     "display_name": "Feminist Epistemology and Gender Studies",
#     "value": 0.0001804,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3312",
#       "display_name": "Sociology and Political Science"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T13368",
#     "display_name": "University Challenges and Reforms",
#     "value": 0.0001172,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3304",
#       "display_name": "Education"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11238",
#     "display_name": "Simulation-Based Education in Healthcare",
#     "value": 0.000113,
#     "subfield": {
#       "id": "https://openalex.org/subfields/2737",
#       "display_name": "Physiology"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/27",
#       "display_name": "Medicine"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T13585",
#     "display_name": "Technostress in Professional Settings",
#     "value": 0.0001061,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3207",
#       "display_name": "Social Psychology"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/32",
#       "display_name": "Psychology"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11028",
#     "display_name": "Social Work Education and Practice",
#     "value": 9.73e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3321",
#       "display_name": "Public Administration"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T13332",
#     "display_name": "Historical Studies on Reproduction, Gender, Health, and Societal Changes",
#     "value": 9.24e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/1202",
#       "display_name": "History"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/12",
#       "display_name": "Arts and Humanities"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T12749",
#     "display_name": "Race, Genetics, and Society",
#     "value": 9.21e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/1311",
#       "display_name": "Genetics"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/13",
#       "display_name": "Biochemistry, Genetics and Molecular Biology"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/1",
#       "display_name": "Life Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T14074",
#     "display_name": "Persona Design and Applications",
#     "value": 7.51e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/1709",
#       "display_name": "Human-Computer Interaction"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/17",
#       "display_name": "Computer Science"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/3",
#       "display_name": "Physical Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11639",
#     "display_name": "Mental Health and Patient Involvement",
#     "value": 7.44e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3600",
#       "display_name": "General Health Professions"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/36",
#       "display_name": "Health Professions"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T13720",
#     "display_name": "Benford\u2019s Law and Fraud Detection",
#     "value": 7.03e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/2613",
#       "display_name": "Statistics and Probability"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/26",
#       "display_name": "Mathematics"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/3",
#       "display_name": "Physical Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T13927",
#     "display_name": "Cyberloafing and Workplace Behavior",
#     "value": 6.63e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3317",
#       "display_name": "Demography"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11497",
#     "display_name": "Interprofessional Education and Collaboration",
#     "value": 6.09e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3600",
#       "display_name": "General Health Professions"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/36",
#       "display_name": "Health Professions"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T12666",
#     "display_name": "Historical Psychiatry and Medical Practices",
#     "value": 5.6e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3203",
#       "display_name": "Clinical Psychology"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/32",
#       "display_name": "Psychology"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T10709",
#     "display_name": "Social Robot Interaction and HRI",
#     "value": 4.9e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3207",
#       "display_name": "Social Psychology"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/32",
#       "display_name": "Psychology"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11645",
#     "display_name": "Urban, Neighborhood, and Segregation Studies",
#     "value": 4.84e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3312",
#       "display_name": "Sociology and Political Science"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T10459",
#     "display_name": "Sexual function and dysfunction studies",
#     "value": 4.84e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/2738",
#       "display_name": "Psychiatry and Mental health"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/27",
#       "display_name": "Medicine"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11464",
#     "display_name": "Homelessness and Social Issues",
#     "value": 4.72e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3600",
#       "display_name": "General Health Professions"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/36",
#       "display_name": "Health Professions"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T10883",
#     "display_name": "Ethics and Social Impacts of AI",
#     "value": 4.71e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3311",
#       "display_name": "Safety Research"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11806",
#     "display_name": "Service-Learning and Community Engagement",
#     "value": 4.71e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3304",
#       "display_name": "Education"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T13700",
#     "display_name": "Gender Studies and Social Issues",
#     "value": 4.59e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3318",
#       "display_name": "Gender Studies"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T10916",
#     "display_name": "Surgical Simulation and Training",
#     "value": 4.34e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/2746",
#       "display_name": "Surgery"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/27",
#       "display_name": "Medicine"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/4",
#       "display_name": "Health Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T12978",
#     "display_name": "Innovative Teaching Methodologies in Social Sciences",
#     "value": 4.28e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3304",
#       "display_name": "Education"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T11120",
#     "display_name": "Nonprofit Sector and Volunteering",
#     "value": 4.04e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/3312",
#       "display_name": "Sociology and Political Science"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/33",
#       "display_name": "Social Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   {
#     "id": "https://openalex.org/T14148",
#     "display_name": "Kierkegaardian Philosophy and Influence",
#     "value": 3.88e-05,
#     "subfield": {
#       "id": "https://openalex.org/subfields/1211",
#       "display_name": "Philosophy"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/12",
#       "display_name": "Arts and Humanities"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   }
# ]

# %% [markdown]
# Topics =
# Works in OpenAlex are tagged with Topics using an automated system that takes into account the available information about the work, including title, abstract, source (journal) name, and citations. There are around 4,500 Topics. Works are assigned topics using a model that assigns scores for each topic for a work. The highest-scoring topic is that work's primary_topic. We also provide additional highly ranked topics for works, in Work.topics.
#
# id = the openAlex Id for this topic
# display_name = english-language label of the topic
#
# domain = ID & highest level in the "domain, field, subfield, topic" system, least granular. See the topics overview for more explanation and a diagram.
#
# field = second-highest level in the "domain, field, subfield, topic" system, second-least granular. See the topics overview for more explanation and a diagram.
#
# subfield = third-highest level in the "domain, field, subfield, topic" system, which means it is the third-least granular.
#
# topic_share = https://help.openalex.org/hc/en-us/articles/27255333459991-What-is-the-difference-between-topics-and-topic-share-in-OpenAlex-entities

# %% [markdown]
# domain > field > subfield > topic

# %% [markdown]
# Each row in the 'topics' column contains a list of research topics the author has worked on, with each topic linked to a 'subfield', 'field', and 'domain', representing different levels of granularity. We use 'domain' because it's the broadest and least granular category (e.g., "Social Sciences", "Health Sciences"), which makes it easier to distinguish researchers by their overall disciplinary focus.
#
# For each researcher, we look at all their topics (e.g., “Homelessness and Social Issues”, “Social Work Education and Practice”). Each topic has a `count` — the number of papers they’ve written in that topic. We group these topics by their associated `domain` (e.g., “Health Sciences”) and sum the counts within each domain. The domain with the highest total count is taken as the researcher’s main area of work.

# %%
# let's try and check out for the first row/ first researcher what would be his/her field after this implementation explained above

df_copy = df_final.copy(deep=True)
first_row_topics = df_copy['topics'].iloc[0]

domain_counts = {}

for topic in first_row_topics:
    domain = topic.get("domain", {}).get("display_name")
    count = topic.get("count", 0)
    display_name = topic.get("display_name", None)
    print(f"Topic: {display_name} | Domain: {domain} | Count: {count}")
    if domain:
        domain_counts[domain] = domain_counts.get(domain, 0) + count

print("\nTotal counts per domain:")
for domain, total in sorted(domain_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{domain}: {total}")

main_domain = max(domain_counts.items(), key=lambda x: x[1])
print(f"\nMost active domain: {main_domain[0]} (Total count: {main_domain[1]})")
# Out:
# Topic: Homelessness and Social Issues | Domain: Health Sciences | Count: 12
# Topic: Social Work Education and Practice | Domain: Social Sciences | Count: 10
# Topic: Historical Studies on Reproduction, Gender, Health, and Societal Changes | Domain: Social Sciences | Count: 9
# Topic: Interprofessional Education and Collaboration | Domain: Health Sciences | Count: 8
# Topic: Mental Health and Patient Involvement | Domain: Health Sciences | Count: 7
# Topic: Simulation-Based Education in Healthcare | Domain: Health Sciences | Count: 7
# Topic: Social and Educational Sciences | Domain: Social Sciences | Count: 7
# Topic: Urban, Neighborhood, and Segregation Studies | Domain: Social Sciences | Count: 6
# Topic: Sexual function and dysfunction studies | Domain: Health Sciences | Count: 5
# Topic: Housing, Finance, and Neoliberalism | Domain: Social Sciences | Count: 4
# Topic: Biomedical Ethics and Regulation | Domain: Health Sciences | Count: 4
# Topic: Sexuality, Behavior, and Technology | Domain: Social Sciences | Count: 4
# Topic: Posthumanist Ethics and Activism | Domain: Social Sciences | Count: 4
# Topic: Empathy and Medical Education | Domain: Health Sciences | Count: 4
# Topic: Surgical Simulation and Training | Domain: Health Sciences | Count: 4
# Topic: Innovations in Medical Education | Domain: Health Sciences | Count: 4
# Topic: Historical Psychiatry and Medical Practices | Domain: Social Sciences | Count: 4
# Topic: Service-Learning and Community Engagement | Domain: Social Sciences | Count: 4
# Topic: Digital Games and Media | Domain: Social Sciences | Count: 3
# Topic: Historical Gender and Feminism Studies | Domain: Social Sciences | Count: 3
# Topic: Nonprofit Sector and Volunteering | Domain: Social Sciences | Count: 3
# Topic: Social Media and Politics | Domain: Social Sciences | Count: 3
# Topic: Ethics and Social Impacts of AI | Domain: Social Sciences | Count: 3
# Topic: Pharmaceutical Economics and Policy | Domain: Social Sciences | Count: 3
# Topic: Race, Genetics, and Society | Domain: Life Sciences | Count: 3
#
# Total counts per domain:
# Social Sciences: 70
# Health Sciences: 55
# Life Sciences: 3
#
# Most active domain: Social Sciences (Total count: 70)

# %% [markdown]
# Now we do it for the complete df_copy, we extract the domain with the highest count per researcher.

# %%
from collections import defaultdict

def get_main_domain_from_topics(topic_list):
    if not isinstance(topic_list, list) or len(topic_list) == 0:
        return None
    
    domain_counts = defaultdict(int)
    
    for topic in topic_list:
        domain = topic.get("domain", {}).get("display_name")
        count = topic.get("count", 0)
        if domain:
            domain_counts[domain] += count
    
    if domain_counts:
        return max(domain_counts.items(), key=lambda x: x[1])[0]
    
    return None

# %%
df_copy['main_domain'] = df_copy['topics'].apply(get_main_domain_from_topics)

# %%
reduced_df = df_copy[['ResponseId', 'works_count', 'cited_by_count', 'counts_by_year', 'affiliations', 'last_known_institutions', 'works_api_url', 'main_domain']]
reduced_df.head()
# Out:
#           ResponseId  works_count  cited_by_count  \
# 0  R_2DUIfkur5fbOgZo          132            1211
# 1  R_46yreKgPLBawn3H           55             813
# 2  R_2ZTGtufLu3KUHW9           30             224
# 3  R_1gzm4gKhyxKNWBW           11              24
# 4  R_3w5HE5P6WKA3ErS           14              24
#
#                                       counts_by_year  \
# 0  [{'year': 2025, 'works_count': 3, 'cited_by_co...
# 1  [{'year': 2025, 'works_count': 0, 'cited_by_co...
# 2  [{'year': 2025, 'works_count': 7, 'cited_by_co...
# 3  [{'year': 2025, 'works_count': 1, 'cited_by_co...
# 4  [{'year': 2025, 'works_count': 1, 'cited_by_co...
#
#                                         affiliations  \
# 0  [{'institution': {'id': 'https://openalex.org/...
# 1  [{'institution': {'id': 'https://openalex.org/...
# 2  [{'institution': {'id': 'https://openalex.org/...
# 3  [{'institution': {'id': 'https://openalex.org/...
# 4  [{'institution': {'id': 'https://openalex.org/...
#
#                              last_known_institutions  \
# 0  [{'id': 'https://openalex.org/I102134673', 'ro...
# 1  [{'id': 'https://openalex.org/I91136226', 'ror...
# 2  [{'id': 'https://openalex.org/I322491407', 'ro...
# 3  [{'id': 'https://openalex.org/I8765205', 'ror'...
# 4  [{'id': 'https://openalex.org/I4210095952', 'r...
#
#                                        works_api_url        main_domain
# 0  https://api.openalex.org/works?filter=author.i...    Social Sciences
# 1  https://api.openalex.org/works?filter=author.i...  Physical Sciences
# 2  https://api.openalex.org/works?filter=author.i...    Health Sciences
# 3  https://api.openalex.org/works?filter=author.i...  Physical Sciences
# 4  https://api.openalex.org/works?filter=author.i...    Social Sciences

# %%
len(reduced_df)
# Out:
# 1195

# %% [markdown]
# Continue getting Orcids from provided Scopus accounts

# %%
def extract_author_id(scopus_url):
    if isinstance(scopus_url, str) and "authorId=" in scopus_url:
        return scopus_url.split("authorId=")[-1].split("&")[0]
    return None

scopus_df['scopus_author_id'] = scopus_df['DE13_5_1'].apply(extract_author_id)
scopus_df
# Out:
#              ResponseId                                           DE13_5_1  \
# 15    R_1gzm4gKhyxKNWBW  https://www.scopus.com/authid/detail.uri?autho...
# 30    R_8S1zWLINCbSqU7z  https://www.scopus.com/authid/detail.uri?autho...
# 33    R_1cVUYTnhvznwxvH  https://www.scopus.com/authid/detail.uri?autho...
# 34    R_22K1UksXA8pHVfq  https://www.scopus.com/authid/detail.uri?autho...
# 54    R_2kREO1n73i4PZbL  https://www.scopus.com/authid/detail.uri?autho...
# ...                 ...                                                ...
# 3144  R_2tDJXr0XU8HlOCQ  https://www.scopus.com/authid/detail.uri?autho...
# 3156  R_2q1rjasYbfm32Tf  https://www.scopus.com/authid/detail.uri?autho...
# 3166  R_25SIA1HKgDT0Eyy  https://www.scopus.com/authid/detail.uri?autho...
# 3209  R_8aTvXnZQE8Gef4J  https://www.scopus.com/authid/detail.uri?autho...
# 3234  R_2iFjsLGZX3qEgu0  https://www.scopus.com/authid/detail.uri?autho...
#
#      scopus_author_id
# 15        58787462900
# 30         9233278800
# 33        57196064572
# 34         7003280394
# 54        56677782000
# ...               ...
# 3144      24477907200
# 3156      57169980900
# 3166      57210829952
# 3209      24166546200
# 3234      26535552300
#
# [180 rows x 3 columns]

# %%
API_KEY = "eb87b01c68aadbda0b3392211176df40" 
HEADERS = {"X-ELS-APIKey": API_KEY, "Accept": "application/json"}

def fetch_author_metadata(author_id):
    if not author_id:
        return None
    url = f"https://api.elsevier.com/content/author/author_id/{author_id}"
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        return response.json()
    return None  

raw_jsons = []
for author_id in scopus_df["scopus_author_id"]:
    raw_jsons.append(fetch_author_metadata(author_id))
    time.sleep(0.5)  

scopus_df["scopus_raw_json"] = raw_jsons

# %%
#scopus_df.to_csv("scopus_author_data.csv", index = False)

# %%
scopus_df = pd.read_csv("scopus_author_data.csv")
scopus_df.head()
# Out:
#           ResponseId                                           DE13_5_1  \
# 0  R_1gzm4gKhyxKNWBW  https://www.scopus.com/authid/detail.uri?autho...
# 1  R_8S1zWLINCbSqU7z  https://www.scopus.com/authid/detail.uri?autho...
# 2  R_1cVUYTnhvznwxvH  https://www.scopus.com/authid/detail.uri?autho...
# 3  R_22K1UksXA8pHVfq  https://www.scopus.com/authid/detail.uri?autho...
# 4  R_2kREO1n73i4PZbL  https://www.scopus.com/authid/detail.uri?autho...
#
#    scopus_author_id                                    scopus_raw_json
# 0      5.878746e+10  {'author-retrieval-response': [{'@status': 'fo...
# 1      9.233279e+09  {'author-retrieval-response': [{'@status': 'fo...
# 2      5.719606e+10  {'author-retrieval-response': [{'@status': 'fo...
# 3      7.003280e+09  {'author-retrieval-response': [{'@status': 'fo...
# 4      5.667778e+10  {'author-retrieval-response': [{'@status': 'fo...

# %%
import ast
import json

first_entry_raw = scopus_df['scopus_raw_json'].iloc[0]
first_entry_dict = ast.literal_eval(first_entry_raw) 
print(json.dumps(first_entry_dict, indent=2))
# Out:
# {
#   "author-retrieval-response": [
#     {
#       "@status": "found",
#       "@_fa": "true",
#       "coredata": {
#         "prism:url": "http://api.elsevier.com/content/author/author_id/58787462900",
#         "dc:identifier": "AUTHOR_ID:58787462900",
#         "eid": "9-s2.0-58787462900",
#         "orcid": "0000-0002-2475-1496",
#         "document-count": "9",
#         "cited-by-count": "24",
#         "citation-count": "30",
#         "link": [
#           {
#             "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=58787462900&origin=inward",
#             "@rel": "scopus-author",
#             "@_fa": "true"
#           },
#           {
#             "@href": "http://api.elsevier.com/content/author/author_id/58787462900",
#             "@rel": "self",
#             "@_fa": "true"
#           },
#           {
#             "@href": "http://api.elsevier.com/content/search/scopus?query=au-id%2858787462900%29",
#             "@rel": "search",
#             "@_fa": "true"
#           }
#         ]
#       },
#       "affiliation-current": {
#         "@id": "118339717",
#         "@href": "http://api.elsevier.com/content/affiliation/affiliation_id/118339717"
#       },
#       "affiliation-history": {
#         "affiliation": [
#           {
#             "@_fa": "true",
#             "@id": "60027251",
#             "@href": "http://api.elsevier.com/content/affiliation/affiliation_id/60027251"
#           }
#         ]
#       },
#       "subject-areas": {
#         "subject-area": [
#           {
#             "@_fa": "true",
#             "@abbrev": "COMP",
#             "@code": "1702",
#             "$": "Artificial Intelligence"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "ENVI",
#             "@code": "2304",
#             "$": "Environmental Chemistry"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "COMP",
#             "@code": "1708",
#             "$": "Hardware and Architecture"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "BUSI",
#             "@code": "1405",
#             "$": "Management of Technology and Innovation"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "ENGI",
#             "@code": "2210",
#             "$": "Mechanical Engineering"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "COMP",
#             "@code": "1703",
#             "$": "Computational Theory and Mathematics"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "MEDI",
#             "@code": "2718",
#             "$": "Health Informatics"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "AGRI",
#             "@code": "1106",
#             "$": "Food Science"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "ENGI",
#             "@code": "2207",
#             "$": "Control and Systems Engineering"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "MATH",
#             "@code": "2614",
#             "$": "Theoretical Computer Science"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "COMP",
#             "@code": "1704",
#             "$": "Computer Graphics and Computer-Aided Design"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "ENER",
#             "@code": "2102",
#             "$": "Energy Engineering and Power Technology"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "MATH",
#             "@code": "2604",
#             "$": "Applied Mathematics"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "COMP",
#             "@code": "1710",
#             "$": "Information Systems"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "COMP",
#             "@code": "1705",
#             "$": "Computer Networks and Communications"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "ENGI",
#             "@code": "2208",
#             "$": "Electrical and Electronic Engineering"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "COMP",
#             "@code": "1706",
#             "$": "Computer Science Applications"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "ENGI",
#             "@code": "2209",
#             "$": "Industrial and Manufacturing Engineering"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "COMP",
#             "@code": "1700",
#             "$": "Computer Science (all)"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "COMP",
#             "@code": "1711",
#             "$": "Signal Processing"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "COMP",
#             "@code": "1712",
#             "$": "Software"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "COMP",
#             "@code": "1701",
#             "$": "Computer Science (miscellaneous)"
#           },
#           {
#             "@_fa": "true",
#             "@abbrev": "ENGI",
#             "@code": "2204",
#             "$": "Biomedical Engineering"
#           }
#         ]
#       },
#       "author-profile": {
#         "status": "update",
#         "date-created": {
#           "@day": "06",
#           "@month": "01",
#           "@year": "2024"
#         },
#         "preferred-name": {
#           "@date-locked": "2024-02-11T11:05:09.772-05:00",
#           "@source": "corrapi-external",
#           "initials": "V.",
#           "indexed-name": "Strilets V.",
#           "surname": "Strilets",
#           "given-name": "Viktoriia"
#         },
#         "name-variant": [
#           {
#             "@doc-count": "1",
#             "@source": "internal-ani",
#             "initials": "S.",
#             "indexed-name": "Viktoriia S.",
#             "surname": "Viktoriia",
#             "given-name": "Strilets"
#           },
#           {
#             "@doc-count": "1",
#             "@source": "internal-ani",
#             "initials": "V.Y.",
#             "indexed-name": "Strilets V.",
#             "surname": "Strilets",
#             "given-name": "Viktoriia Y."
#           }
#         ],
#         "classificationgroup": {
#           "classifications": {
#             "@type": "ASJC",
#             "classification": [
#               {
#                 "@frequency": "1",
#                 "$": "1702"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "2304"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "1708"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "1405"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "2210"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "1703"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "2718"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "1106"
#               },
#               {
#                 "@frequency": "3",
#                 "$": "2207"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "2614"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "1704"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "2102"
#               },
#               {
#                 "@frequency": "2",
#                 "$": "2604"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "1710"
#               },
#               {
#                 "@frequency": "2",
#                 "$": "1705"
#               },
#               {
#                 "@frequency": "2",
#                 "$": "2208"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "1706"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "2209"
#               },
#               {
#                 "@frequency": "4",
#                 "$": "1700"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "1711"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "1712"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "1701"
#               },
#               {
#                 "@frequency": "1",
#                 "$": "2204"
#               }
#             ]
#           }
#         },
#         "publication-range": {
#           "@end": "2024",
#           "@start": "2019"
#         },
#         "affiliation-current": {
#           "affiliation": {
#             "@affiliation-id": "118339717",
#             "@parent": "60027251",
#             "@source": "internal-ani",
#             "ip-doc": {
#               "@id": "118339717",
#               "@type": "dept",
#               "@relationship": "author",
#               "afdispname": "V. N. Karazin Kharkiv National University, Department of Theoretical and Applied Systems Engineering",
#               "preferred-name": {
#                 "@source": "internal-ani",
#                 "$": "Department of Theoretical and Applied Systems Engineering"
#               },
#               "parent-preferred-name": {
#                 "@source": "internal-ani",
#                 "$": "V. N. Karazin Kharkiv National University"
#               },
#               "sort-name": "Department of Theoretical and Applied Systems Engineering",
#               "address": {
#                 "@country": "ukr",
#                 "address-part": "4 Svobody sq.",
#                 "city": "Kharkiv",
#                 "state": "Kharkiv Oblast",
#                 "postal-code": "61022",
#                 "country": "Ukraine"
#               },
#               "org-domain": "karazin.ua",
#               "org-URL": "https://karazin.ua/en/"
#             }
#           }
#         },
#         "affiliation-history": {
#           "affiliation": [
#             {
#               "@affiliation-id": "118339717",
#               "@parent": "60027251",
#               "@source": "internal-ani",
#               "ip-doc": {
#                 "@id": "118339717",
#                 "@type": "dept",
#                 "@relationship": "author",
#                 "afdispname": "V. N. Karazin Kharkiv National University, Department of Theoretical and Applied Systems Engineering",
#                 "preferred-name": {
#                   "@source": "internal-ani",
#                   "$": "Department of Theoretical and Applied Systems Engineering"
#                 },
#                 "parent-preferred-name": {
#                   "@source": "internal-ani",
#                   "$": "V. N. Karazin Kharkiv National University"
#                 },
#                 "sort-name": "Department of Theoretical and Applied Systems Engineering",
#                 "address": {
#                   "@country": "ukr",
#                   "address-part": "4 Svobody sq.",
#                   "city": "Kharkiv",
#                   "state": "Kharkiv Oblast",
#                   "postal-code": "61022",
#                   "country": "Ukraine"
#                 },
#                 "org-domain": "karazin.ua",
#                 "org-URL": "https://karazin.ua/en/"
#               }
#             },
#             {
#               "@affiliation-id": "60027251",
#               "@source": "internal-ani",
#               "ip-doc": {
#                 "@id": "60027251",
#                 "@type": "parent",
#                 "@relationship": "author",
#                 "afnameid": "V. N. Karazin Kharkiv National University#60027251",
#                 "afdispname": "V. N. Karazin Kharkiv National University",
#                 "preferred-name": {
#                   "@source": "internal-ani",
#                   "$": "V. N. Karazin Kharkiv National University"
#                 },
#                 "sort-name": "V. N. Karazin Kharkiv National University",
#                 "address": {
#                   "@country": "ukr",
#                   "address-part": "4 Svobody sq.",
#                   "city": "Kharkiv",
#                   "state": "Kharkiv Oblast",
#                   "postal-code": "61022",
#                   "country": "Ukraine"
#                 },
#                 "org-domain": "karazin.ua",
#                 "org-URL": "https://karazin.ua/en/"
#               }
#             }
#           ]
#         }
#       }
#     }
#   ]
# }

# %%
def safe_literal_eval(val):
    if pd.isna(val):
        return None
    try:
        return ast.literal_eval(val)
    except Exception as e:
        print(f"Skipping value due to error: {e}")
        return None

scopus_df["scopus_raw_json"] = scopus_df["scopus_raw_json"].apply(safe_literal_eval)

# %%
# how can we get the orcid
i = 0  
scopus_df["scopus_raw_json"].iloc[i]["author-retrieval-response"][0]["coredata"]["orcid"]
# Out:
# '0000-0002-2475-1496'

# %%
def extract_orcid(entry):
    try:
        return entry["author-retrieval-response"][0]["coredata"].get("orcid")
    except (TypeError, KeyError, IndexError):
        return None

scopus_df["orcid"] = scopus_df["scopus_raw_json"].apply(extract_orcid)

# %%
scopus_df
# Out:
#             ResponseId                                           DE13_5_1  \
# 0    R_1gzm4gKhyxKNWBW  https://www.scopus.com/authid/detail.uri?autho...
# 1    R_8S1zWLINCbSqU7z  https://www.scopus.com/authid/detail.uri?autho...
# 2    R_1cVUYTnhvznwxvH  https://www.scopus.com/authid/detail.uri?autho...
# 3    R_22K1UksXA8pHVfq  https://www.scopus.com/authid/detail.uri?autho...
# 4    R_2kREO1n73i4PZbL  https://www.scopus.com/authid/detail.uri?autho...
# ..                 ...                                                ...
# 175  R_2tDJXr0XU8HlOCQ  https://www.scopus.com/authid/detail.uri?autho...
# 176  R_2q1rjasYbfm32Tf  https://www.scopus.com/authid/detail.uri?autho...
# 177  R_25SIA1HKgDT0Eyy  https://www.scopus.com/authid/detail.uri?autho...
# 178  R_8aTvXnZQE8Gef4J  https://www.scopus.com/authid/detail.uri?autho...
# 179  R_2iFjsLGZX3qEgu0  https://www.scopus.com/authid/detail.uri?autho...
#
#      scopus_author_id                                    scopus_raw_json  \
# 0        5.878746e+10  {'author-retrieval-response': [{'@status': 'fo...
# 1        9.233279e+09  {'author-retrieval-response': [{'@status': 'fo...
# 2        5.719606e+10  {'author-retrieval-response': [{'@status': 'fo...
# 3        7.003280e+09  {'author-retrieval-response': [{'@status': 'fo...
# 4        5.667778e+10  {'author-retrieval-response': [{'@status': 'fo...
# ..                ...                                                ...
# 175      2.447791e+10  {'author-retrieval-response': [{'@status': 'fo...
# 176      5.716998e+10  {'author-retrieval-response': [{'@status': 'fo...
# 177      5.721083e+10  {'author-retrieval-response': [{'@status': 'fo...
# 178      2.416655e+10  {'author-retrieval-response': [{'@status': 'fo...
# 179      2.653555e+10  {'author-retrieval-response': [{'@status': 'fo...
#
#                    orcid
# 0    0000-0002-2475-1496
# 1    0000-0003-4552-1953
# 2    0000-0002-5089-7552
# 3    0000-0001-7583-9976
# 4    0000-0002-1086-9274
# ..                   ...
# 175  0000-0002-7262-6788
# 176  0000-0003-1588-4294
# 177  0000-0001-6611-5298
# 178  0000-0002-3254-0365
# 179  0000-0002-9203-7550
#
# [180 rows x 5 columns]

# %%
# I will use the function from above where I standardized all available orcids I had already
scopus_df["orcid_standard"] = scopus_df["orcid"].apply(extract_canonical_orcid)

# %%
# did it fail somewhere?
missing_df_scopus = scopus_df[scopus_df["orcid_standard"].isna()].copy()
print(f"{len(missing_df_scopus)} rows in scopus_df failed to yield a valid ORCID.")
# Out:
# 71 rows in scopus_df failed to yield a valid ORCID.

# %%
#missing_df_scopus.to_csv("not_found_orcids_on_scopus.csv", index=False)

# %%
missing_df_scopus = pd.read_csv("not_found_orcids_on_scopus.csv")
missing_df_scopus.head()
len(missing_df_scopus)
# Out:
# 71

# %%
# we remove the missing ones and create a new df with only relevant cols for now
# then we call openAlex API providing the new orcids of researchers that provided scopus Id
scopus_orcid_df = scopus_df[scopus_df["orcid_standard"].notna()].copy()
scopus_orcid_df = scopus_orcid_df[["ResponseId", "scopus_author_id", "orcid_standard"]]

scopus_orcid_df["retrieved_author_data"] = scopus_orcid_df.apply(get_author_id, axis=1)
scopus_orcid_df
# Out:
#             ResponseId  scopus_author_id  \
# 0    R_1gzm4gKhyxKNWBW      5.878746e+10
# 1    R_8S1zWLINCbSqU7z      9.233279e+09
# 2    R_1cVUYTnhvznwxvH      5.719606e+10
# 3    R_22K1UksXA8pHVfq      7.003280e+09
# 4    R_2kREO1n73i4PZbL      5.667778e+10
# ..                 ...               ...
# 175  R_2tDJXr0XU8HlOCQ      2.447791e+10
# 176  R_2q1rjasYbfm32Tf      5.716998e+10
# 177  R_25SIA1HKgDT0Eyy      5.721083e+10
# 178  R_8aTvXnZQE8Gef4J      2.416655e+10
# 179  R_2iFjsLGZX3qEgu0      2.653555e+10
#
#                             orcid_standard  \
# 0    https://orcid.org/0000-0002-2475-1496
# 1    https://orcid.org/0000-0003-4552-1953
# 2    https://orcid.org/0000-0002-5089-7552
# 3    https://orcid.org/0000-0001-7583-9976
# 4    https://orcid.org/0000-0002-1086-9274
# ..                                     ...
# 175  https://orcid.org/0000-0002-7262-6788
# 176  https://orcid.org/0000-0003-1588-4294
# 177  https://orcid.org/0000-0001-6611-5298
# 178  https://orcid.org/0000-0002-3254-0365
# 179  https://orcid.org/0000-0002-9203-7550
#
#                                  retrieved_author_data
# 0    {'id': 'https://openalex.org/A5087740005', 'or...
# 1    {'id': 'https://openalex.org/A5059677224', 'or...
# 2    {'id': 'https://openalex.org/A5041741412', 'or...
# 3    {'id': 'https://openalex.org/A5028772814', 'or...
# 4    {'id': 'https://openalex.org/A5000407091', 'or...
# ..                                                 ...
# 175  {'id': 'https://openalex.org/A5006670161', 'or...
# 176  {'id': 'https://openalex.org/A5005026314', 'or...
# 177  {'id': 'https://openalex.org/A5090876368', 'or...
# 178  {'id': 'https://openalex.org/A5059337122', 'or...
# 179  {'id': 'https://openalex.org/A5083904390', 'or...
#
# [109 rows x 4 columns]

# %%
num_missing_scopus_orcids = scopus_orcid_df['retrieved_author_data'].isna().sum()
print(f"{num_missing_scopus_orcids} rows in 'retrieved_author_data' are NaN or empty/null")

num_missing_scopus_orcids = scopus_orcid_df[scopus_orcid_df['retrieved_author_data'].isna()]
num_missing_scopus_orcids
# Out:
# 1 rows in 'retrieved_author_data' are NaN or empty/null
#           ResponseId  scopus_author_id                         orcid_standard  \
# 7  R_27eCdCht7JBsF9M      5.720982e+10  https://orcid.org/0000-0003-2545-6314
#
#   retrieved_author_data
# 7                  None

# %%
scopus_orcids_df_clean_no_missing = scopus_orcid_df[~scopus_orcid_df['ResponseId'].isin(num_missing_scopus_orcids['ResponseId'])]
scopus_orcids_df_clean_no_missing.reset_index(drop=True, inplace=True)
len(scopus_orcids_df_clean_no_missing)
# Out:
# 108

# %%
scopus_orcids_df_clean_no_missing.to_pickle("Scopus_Orcids_Scrape_on_oA.pkl")
num_missing_scopus_orcids.to_pickle("not_found_scopus_orcid_on_oA.pkl")

# %%
scopus_orcids_scrape_df = pd.read_pickle("Scopus_Orcids_Scrape_on_oA.pkl")
scopus_orcids_scrape_df.head()
# Out:
#           ResponseId  scopus_author_id                         orcid_standard  \
# 0  R_1gzm4gKhyxKNWBW      5.878746e+10  https://orcid.org/0000-0002-2475-1496
# 1  R_8S1zWLINCbSqU7z      9.233279e+09  https://orcid.org/0000-0003-4552-1953
# 2  R_1cVUYTnhvznwxvH      5.719606e+10  https://orcid.org/0000-0002-5089-7552
# 3  R_22K1UksXA8pHVfq      7.003280e+09  https://orcid.org/0000-0001-7583-9976
# 4  R_2kREO1n73i4PZbL      5.667778e+10  https://orcid.org/0000-0002-1086-9274
#
#                                retrieved_author_data
# 0  {'id': 'https://openalex.org/A5087740005', 'or...
# 1  {'id': 'https://openalex.org/A5059677224', 'or...
# 2  {'id': 'https://openalex.org/A5041741412', 'or...
# 3  {'id': 'https://openalex.org/A5028772814', 'or...
# 4  {'id': 'https://openalex.org/A5000407091', 'or...

# %%
df_scopus_orcid = scopus_orcids_scrape_df.copy()
df_scopus_orcid_normal = scopus_orcids_scrape_df['retrieved_author_data'].apply(pd.Series)
df_final_scop_orc = pd.concat([df_scopus_orcid[['ResponseId']], df_scopus_orcid_normal], axis=1)
df_final_scop_orc.head()
#df_final_scop_orc = pd.concat([df_scopus_orcid[['ResponseId']], df_scopus_orcid_normal], axis=1)
#df_final_scop_orc.head()
# Out:
#           ResponseId                                id  \
# 0  R_1gzm4gKhyxKNWBW  https://openalex.org/A5087740005
# 1  R_8S1zWLINCbSqU7z  https://openalex.org/A5059677224
# 2  R_1cVUYTnhvznwxvH  https://openalex.org/A5041741412
# 3  R_22K1UksXA8pHVfq  https://openalex.org/A5028772814
# 4  R_2kREO1n73i4PZbL  https://openalex.org/A5000407091
#
#                                    orcid           display_name  \
# 0  https://orcid.org/0000-0002-2475-1496     Viktoriia Strilets
# 1  https://orcid.org/0000-0003-4552-1953         João Rodrigues
# 2  https://orcid.org/0000-0002-5089-7552          Vesela Mihova
# 3  https://orcid.org/0000-0001-7583-9976            Oleg Akimov
# 4  https://orcid.org/0000-0002-1086-9274  Oleksandr P. Krupskyi
#
#                            display_name_alternatives  works_count  \
# 0  [V. Y. Strilets, Viktoriia Strilets, Valerii S...           11
# 1  [J. Rodrigues, J. Rodrígues, Joáo Rodrigues, R...          168
# 2             [V A Mihova, Vesela Mihova, V. Mihova]           22
# 3  [Oleg Akimov, О. В. Акимов, O. Akimov, Олег Ві...           64
# 4  [Оleksandr Krupskyi, Oleksandr‐P. Krupskyi, Ol...          118
#
#    cited_by_count                                      summary_stats  \
# 0              24  {'2yr_mean_citedness': 1.0, 'h_index': 3, 'i10...
# 1            6620  {'2yr_mean_citedness': 11.586206896551724, 'h_...
# 2             136  {'2yr_mean_citedness': 0.6666666666666666, 'h_...
# 3             124  {'2yr_mean_citedness': 0.0, 'h_index': 6, 'i10...
# 4             349  {'2yr_mean_citedness': 1.2608695652173914, 'h_...
#
#                                                  ids  \
# 0  {'openalex': 'https://openalex.org/A5087740005...
# 1  {'openalex': 'https://openalex.org/A5059677224...
# 2  {'openalex': 'https://openalex.org/A5041741412...
# 3  {'openalex': 'https://openalex.org/A5028772814...
# 4  {'openalex': 'https://openalex.org/A5000407091...
#
#                                         affiliations  \
# 0  [{'institution': {'id': 'https://openalex.org/...
# 1  [{'institution': {'id': 'https://openalex.org/...
# 2  [{'institution': {'id': 'https://openalex.org/...
# 3  [{'institution': {'id': 'https://openalex.org/...
# 4  [{'institution': {'id': 'https://openalex.org/...
#
#                              last_known_institutions  \
# 0  [{'id': 'https://openalex.org/I8765205', 'ror'...
# 1  [{'id': 'https://openalex.org/I58028834', 'ror...
# 2  [{'id': 'https://openalex.org/I43986944', 'ror...
# 3  [{'id': 'https://openalex.org/I67256668', 'ror...
# 4  [{'id': 'https://openalex.org/I883679329', 'ro...
#
#                                               topics  \
# 0  [{'id': 'https://openalex.org/T11396', 'displa...
# 1  [{'id': 'https://openalex.org/T11686', 'displa...
# 2  [{'id': 'https://openalex.org/T10282', 'displa...
# 3  [{'id': 'https://openalex.org/T13129', 'displa...
# 4  [{'id': 'https://openalex.org/T12922', 'displa...
#
#                                          topic_share  \
# 0  [{'id': 'https://openalex.org/T13608', 'displa...
# 1  [{'id': 'https://openalex.org/T11686', 'displa...
# 2  [{'id': 'https://openalex.org/T14406', 'displa...
# 3  [{'id': 'https://openalex.org/T14454', 'displa...
# 4  [{'id': 'https://openalex.org/T13411', 'displa...
#
#                                           x_concepts  \
# 0  [{'id': 'https://openalex.org/C41008148', 'wik...
# 1  [{'id': 'https://openalex.org/C185592680', 'wi...
# 2  [{'id': 'https://openalex.org/C41008148', 'wik...
# 3  [{'id': 'https://openalex.org/C121332964', 'wi...
# 4  [{'id': 'https://openalex.org/C17744445', 'wik...
#
#                                       counts_by_year  \
# 0  [{'year': 2025, 'works_count': 1, 'cited_by_co...
# 1  [{'year': 2025, 'works_count': 6, 'cited_by_co...
# 2  [{'year': 2025, 'works_count': 1, 'cited_by_co...
# 3  [{'year': 2025, 'works_count': 1, 'cited_by_co...
# 4  [{'year': 2025, 'works_count': 13, 'cited_by_c...
#
#                                        works_api_url  \
# 0  https://api.openalex.org/works?filter=author.i...
# 1  https://api.openalex.org/works?filter=author.i...
# 2  https://api.openalex.org/works?filter=author.i...
# 3  https://api.openalex.org/works?filter=author.i...
# 4  https://api.openalex.org/works?filter=author.i...
#
#                  updated_date created_date
# 0  2025-06-23T02:41:38.495338   2023-07-21
# 1  2025-06-21T08:59:24.631860   2023-07-21
# 2  2025-06-19T04:01:40.873122   2023-07-21
# 3  2025-06-24T20:46:26.428495   2023-07-21
# 4  2025-06-18T07:40:32.013220   2023-07-21

# %%
# I will run the function I created above to extract the domain of the researchers
df_final_scop_orc['main_domain'] = df_final_scop_orc['topics'].apply(get_main_domain_from_topics)

# %%
reduced_df_scop_orcid = df_final_scop_orc[['ResponseId', 'works_count', 'cited_by_count', 'counts_by_year', 'affiliations', 'last_known_institutions', 'works_api_url', 'main_domain']]
len(reduced_df_scop_orcid)
reduced_df_scop_orcid.head()
# Out:
#           ResponseId  works_count  cited_by_count  \
# 0  R_1gzm4gKhyxKNWBW           11              24
# 1  R_8S1zWLINCbSqU7z          168            6620
# 2  R_1cVUYTnhvznwxvH           22             136
# 3  R_22K1UksXA8pHVfq           64             124
# 4  R_2kREO1n73i4PZbL          118             349
#
#                                       counts_by_year  \
# 0  [{'year': 2025, 'works_count': 1, 'cited_by_co...
# 1  [{'year': 2025, 'works_count': 6, 'cited_by_co...
# 2  [{'year': 2025, 'works_count': 1, 'cited_by_co...
# 3  [{'year': 2025, 'works_count': 1, 'cited_by_co...
# 4  [{'year': 2025, 'works_count': 13, 'cited_by_c...
#
#                                         affiliations  \
# 0  [{'institution': {'id': 'https://openalex.org/...
# 1  [{'institution': {'id': 'https://openalex.org/...
# 2  [{'institution': {'id': 'https://openalex.org/...
# 3  [{'institution': {'id': 'https://openalex.org/...
# 4  [{'institution': {'id': 'https://openalex.org/...
#
#                              last_known_institutions  \
# 0  [{'id': 'https://openalex.org/I8765205', 'ror'...
# 1  [{'id': 'https://openalex.org/I58028834', 'ror...
# 2  [{'id': 'https://openalex.org/I43986944', 'ror...
# 3  [{'id': 'https://openalex.org/I67256668', 'ror...
# 4  [{'id': 'https://openalex.org/I883679329', 'ro...
#
#                                        works_api_url        main_domain
# 0  https://api.openalex.org/works?filter=author.i...  Physical Sciences
# 1  https://api.openalex.org/works?filter=author.i...  Physical Sciences
# 2  https://api.openalex.org/works?filter=author.i...    Social Sciences
# 3  https://api.openalex.org/works?filter=author.i...  Physical Sciences
# 4  https://api.openalex.org/works?filter=author.i...    Social Sciences

# %%
# any missing?
empty_main_domain_rows = reduced_df_scop_orcid[reduced_df_scop_orcid['main_domain'].isna() | (reduced_df_scop_orcid['main_domain'] == "")]
empty_main_domain_rows
# Out:
# Empty DataFrame
# Columns: [ResponseId, works_count, cited_by_count, counts_by_year, affiliations, last_known_institutions, works_api_url, main_domain]
# Index: []

# %%
# Check for overlap
overlap = set(reduced_df['ResponseId']).intersection(set(reduced_df_scop_orcid['ResponseId']))
len(overlap)
# Out:
# 83

# %%
combined_df = pd.concat([reduced_df, reduced_df_scop_orcid], ignore_index=True)

combined_df = combined_df.drop_duplicates(subset='ResponseId', keep='first')

print(f"Combined shape: {combined_df.shape}")
combined_df.head()
# Out:
# Combined shape: (1220, 8)
#           ResponseId  works_count  cited_by_count  \
# 0  R_2DUIfkur5fbOgZo          132            1211
# 1  R_46yreKgPLBawn3H           55             813
# 2  R_2ZTGtufLu3KUHW9           30             224
# 3  R_1gzm4gKhyxKNWBW           11              24
# 4  R_3w5HE5P6WKA3ErS           14              24
#
#                                       counts_by_year  \
# 0  [{'year': 2025, 'works_count': 3, 'cited_by_co...
# 1  [{'year': 2025, 'works_count': 0, 'cited_by_co...
# 2  [{'year': 2025, 'works_count': 7, 'cited_by_co...
# 3  [{'year': 2025, 'works_count': 1, 'cited_by_co...
# 4  [{'year': 2025, 'works_count': 1, 'cited_by_co...
#
#                                         affiliations  \
# 0  [{'institution': {'id': 'https://openalex.org/...
# 1  [{'institution': {'id': 'https://openalex.org/...
# 2  [{'institution': {'id': 'https://openalex.org/...
# 3  [{'institution': {'id': 'https://openalex.org/...
# 4  [{'institution': {'id': 'https://openalex.org/...
#
#                              last_known_institutions  \
# 0  [{'id': 'https://openalex.org/I102134673', 'ro...
# 1  [{'id': 'https://openalex.org/I91136226', 'ror...
# 2  [{'id': 'https://openalex.org/I322491407', 'ro...
# 3  [{'id': 'https://openalex.org/I8765205', 'ror'...
# 4  [{'id': 'https://openalex.org/I4210095952', 'r...
#
#                                        works_api_url        main_domain
# 0  https://api.openalex.org/works?filter=author.i...    Social Sciences
# 1  https://api.openalex.org/works?filter=author.i...  Physical Sciences
# 2  https://api.openalex.org/works?filter=author.i...    Health Sciences
# 3  https://api.openalex.org/works?filter=author.i...  Physical Sciences
# 4  https://api.openalex.org/works?filter=author.i...    Social Sciences

# %%
orcid_and_scopus_df = combined_df.copy()
orcid_and_scopus_df.to_pickle("orcid_and_scopus_from_oA_combined.pkl")

# %%
len(orcid_and_scopus_df)
# Out:
# 1220

# %%
# what is the content in col counts_by_year?
first_entry = orcid_and_scopus_df['counts_by_year'].iloc[0]
print(json.dumps(first_entry, indent=2))
# Out:
# [
#   {
#     "year": 2025,
#     "works_count": 3,
#     "cited_by_count": 33
#   },
#   {
#     "year": 2024,
#     "works_count": 2,
#     "cited_by_count": 80
#   },
#   {
#     "year": 2023,
#     "works_count": 7,
#     "cited_by_count": 78
#   },
#   {
#     "year": 2022,
#     "works_count": 1,
#     "cited_by_count": 44
#   },
#   {
#     "year": 2021,
#     "works_count": 7,
#     "cited_by_count": 52
#   },
#   {
#     "year": 2020,
#     "works_count": 3,
#     "cited_by_count": 56
#   },
#   {
#     "year": 2019,
#     "works_count": 12,
#     "cited_by_count": 59
#   },
#   {
#     "year": 2018,
#     "works_count": 3,
#     "cited_by_count": 41
#   },
#   {
#     "year": 2017,
#     "works_count": 6,
#     "cited_by_count": 57
#   },
#   {
#     "year": 2016,
#     "works_count": 13,
#     "cited_by_count": 69
#   },
#   {
#     "year": 2015,
#     "works_count": 1,
#     "cited_by_count": 54
#   },
#   {
#     "year": 2014,
#     "works_count": 1,
#     "cited_by_count": 38
#   },
#   {
#     "year": 2013,
#     "works_count": 2,
#     "cited_by_count": 62
#   },
#   {
#     "year": 2012,
#     "works_count": 6,
#     "cited_by_count": 69
#   }
# ]

# %%
# do all of them have structured entries?
def is_valid_entry(entry):
    if not isinstance(entry, list):
        return False
    for item in entry:
        if not isinstance(item, dict):
            return False
        if not all(k in item for k in ['year', 'works_count', 'cited_by_count']):
            return False
    return True

validity_mask = orcid_and_scopus_df['counts_by_year'].apply(is_valid_entry)

print(f"{validity_mask.sum()} out of {len(validity_mask)} entries are well-structured.")
# Out:
# 1220 out of 1220 entries are well-structured.

# %% [markdown]
# ### Increase by Serp API with GoogleScholar accounts

# %%
import re

# need to ut google scholar user id from the url

def extract_user_id(entry):
    if isinstance(entry, str):
        # check if already a clean userid
        if re.fullmatch(r'[a-zA-Z0-9_-]{5,}', entry.strip()):
            return entry.strip()
        # extract userid from url
        if 'user=' in entry:
            return entry.split("user=")[-1].split("&")[0].strip()
    return None

gs_df["user_id"] = gs_df["DE13_1_1"].apply(extract_user_id)

# %%
gs_df.head()
# Out:
#            ResponseId                                           DE13_1_1  \
# 2   R_4pD7OrlAt0l6mjL  https://scholar.google.com/citations?user=Guhy...
# 3   R_7OE9SfkJJ6q9jbP  https://scholar.google.com/citations?user=BSke...
# 11  R_62ojVyfY2SdzKN0  https://scholar.google.com/scholar?hl=en&as_sd...
# 23  R_2B4eUokwACUsT08  https://scholar.google.com/citations?user=DCWk...
# 27  R_2JTY94aJonph8Qx  https://scholar.google.it/citations?user=Uyrfi...
#
#          user_id
# 2   GuhyORoAAAAJ
# 3   BSkeONEAAAAJ
# 11          None
# 23  DCWkn9sAAAAJ
# 27  UyrfibgAAAAJ

# %%
# Show rows where user_id is None, NaN, or 0
mask = (gs_df['user_id'].isna()) | (gs_df['user_id'].eq(None)) | (gs_df['user_id'] == 0)
gs_df[mask]
# Out:
#              ResponseId                                           DE13_1_1  \
# 11    R_62ojVyfY2SdzKN0  https://scholar.google.com/scholar?hl=en&as_sd...
# 89    R_2gESUa3jSIlreut  https://scholar.google.com/scholar?hl=pl&as_sd...
# 107   R_86fDotargQC1YOh  https://scholar.google.be/scholar?hl=nl&as_sdt...
# 340   R_84BIAAeGyGEwNcq  https://scholar.google.com/scholar?hl=fr&as_sd...
# 509   R_8IuhasFPlu8kYYV  https://scholar.google.com/scholar?hl=no&as_sd...
# 707   R_4dEt5R2bLqUQcnm  https://scholar.google.com/scholar?hl=tr&as_sd...
# 783   R_27e32EDeDlr8eyU                        https://scholar.google.com/
# 793   R_2PTUfMJo9yWrdOr  https://www.google.com/search?q=claudia+diehl+...
# 850   R_2Eau6BBwERmShZW              https://orcid.org/0000-0002-9925-2173
# 983   R_82ms9cdQFpWuwkZ  https://www.bwi.uni-stuttgart.de/institut/team...
# 1055  R_8CCkNI8Z3O1AgJt  https://scholar.google.com/scholar?hl=fr&as_sd...
# 1075  R_2EnQS3mqO9PZICY  https://scholar.google.com/scholar?hl=de&as_sd...
# 1436  R_8bIVRT6jaNhc7Ox                                                  4
# 1482  R_83dmlMIR7Ig7xuB  https://scholar.google.com/scholar?hl=de&as_sd...
# 1525  R_2WBbA5lTecRmhko                        https://scholar.google.com/
# 1596  R_2UhWPd29jTZYebP                                      Marcus Clauss
# 1602  R_8iKim8BvrgCv1mH  https://scholar.google.com/scholar?hl=en&as_sd...
# 1820  R_82omyzLPNQrS0IG  https://ncl.instructure.com/courses/52235/page...
# 1829  R_8x7fduo2AvdwBkR                                    Christiaan Lako
# 1855  R_8kZXVqLOXBTaOde              https://orcid.org/0000-0002-8612-8384
# 1882  R_8G0UVGRqhgMuB0K  https://scholar.google.com/scholar?hl=en&as_sd...
# 1908  R_8YJo0JiYAO05GY0  https://scholar.google.es/scholar?hl=es&as_sdt...
# 2041  R_8rqYxNjeBgRBxaV  https://scholar.google.com/scholar?hl=de&as_sd...
# 2148  R_8KeSsD1PPVzeeqq  https://scholar.google.com/citations?view_op=s...
# 2317  R_2f9c6x64huvFJNT                                  Pedro A B Pereira
# 2361  R_8NqambgHjXl7OH1  https://scholar.google.de/citations?view_op=se...
# 2384  R_20uUWA3I0yIii5o              https://lse.academia.edu/PollyWithers
# 2420  R_8E6TxsmC3N0vTnS  https://scholar.google.co.uk/scholar?hl=en&as_...
# 2456  R_2aK4JfekGKINmdg  https://scholar.google.com/scholar?hl=en&as_sd...
# 2471  R_2Rq53NfGiIBoDUB  https://scholar.google.com/scholar?hl=ro&as_sd...
# 2590  R_8v8lz7mO9Z1e0G1                                  Saim Turgut Kocak
# 2720  R_8nkOspKXDSgTkwW  https://scholar.google.com/scholar?hl=en&as_sd...
# 2732  R_21Ga2E8l87pm1gJ  https://scholar.google.com/scholar?hl=sv&as_sd...
# 2867  R_8MawbNha5CAfAIh  https://scholar.google.com/citations?view_op=s...
# 2921  R_8e8R3Duc2zTjqW9  https://scholar.google.com/scholar?hl=ro&as_sd...
# 2948  R_2lXMPzg7ySiwPlY  https://orcid.org/my-orcid?orcid=0000-0002-880...
# 3033  R_8wNZZAOwyPReYVz          https://myaccount.google.com/?hl=fr&pli=1
# 3169  R_22D01Z9z86HO661  https://scholar.google.nl/scholar?hl=nl&as_sdt...
# 3172  R_26pQAbsG5dep7vX  https://scholar.google.nl/scholar?hl=nl&as_sdt...
# 3221  R_22XNIgVR3qFs6wn  https://orcid.org/my-orcid?orcid=0000-0002-623...
# 3230  R_2sTEG4FLmmU8kOm  https://www.webofscience.com/wos/woscc/basic-s...
#
#      user_id
# 11      None
# 89      None
# 107     None
# 340     None
# 509     None
# 707     None
# 783     None
# 793     None
# 850     None
# 983     None
# 1055    None
# 1075    None
# 1436    None
# 1482    None
# 1525    None
# 1596    None
# 1602    None
# 1820    None
# 1829    None
# 1855    None
# 1882    None
# 1908    None
# 2041    None
# 2148    None
# 2317    None
# 2361    None
# 2384    None
# 2420    None
# 2456    None
# 2471    None
# 2590    None
# 2720    None
# 2732    None
# 2867    None
# 2921    None
# 2948    None
# 3033    None
# 3169    None
# 3172    None
# 3221    None
# 3230    None

# %%
# so these below, instead of the userId url they apparently provided their urls with their names
# this introduces disambuiguation, I'll return later to these. We also see some Orcids and other
gs_df.loc[11, 'DE13_1_1']
# Out:
# 'https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=Piotr+Jedrzejowicz&btnG='

# %%
gs_df.loc[89, 'DE13_1_1']
# Out:
# 'https://scholar.google.com/scholar?hl=pl&as_sdt=0%2C5&q=Renata+Ku%C5%9Bmierek-Tomaszewska+&btnG='

# %%
from serpapi import GoogleSearch
import time

# function to fetch raw author data from SerpAPI
def get_raw_author_data_serpAPI(row):
    author_id = row['user_id']  

    if not isinstance(author_id, str) or not author_id.strip():          #
        print(f"Skipping row with invalid author_id: {author_id}")
        return None
    
    api_key = ""  
    params = {
        "engine": "google_scholar_author",
        "author_id": author_id,
        "api_key": api_key,
        "hl": "en"
    }

    try:
        search = GoogleSearch(params)
        result = search.get_dict()
        time.sleep(1)  
        return result
    except Exception as e:
        print(f"Error for author ID {author_id}: {e}")
        return None

# %%
# try with the first 5 rows only
sample_df = gs_df.head(5).copy()
sample_df["raw_author_data"] = sample_df.apply(get_raw_author_data_serpAPI, axis=1)
sample_df
# Out:
# Skipping row with invalid author_id: None
#            ResponseId                                           DE13_1_1  \
# 2   R_4pD7OrlAt0l6mjL  https://scholar.google.com/citations?user=Guhy...
# 3   R_7OE9SfkJJ6q9jbP  https://scholar.google.com/citations?user=BSke...
# 11  R_62ojVyfY2SdzKN0  https://scholar.google.com/scholar?hl=en&as_sd...
# 23  R_2B4eUokwACUsT08  https://scholar.google.com/citations?user=DCWk...
# 27  R_2JTY94aJonph8Qx  https://scholar.google.it/citations?user=Uyrfi...
#
#          user_id                                    raw_author_data
# 2   GuhyORoAAAAJ  {'search_metadata': {'id': '687f2661c4f20f38d6...
# 3   BSkeONEAAAAJ  {'search_metadata': {'id': '687f2664ccb1e94fa5...
# 11          None                                               None
# 23  DCWkn9sAAAAJ  {'search_metadata': {'id': '687f26665b92f8211a...
# 27  UyrfibgAAAAJ  {'search_metadata': {'id': '687f2667f5d5ac9435...

# %%
# now all rows
gs_df["raw_author_data"] = gs_df.apply(get_raw_author_data_serpAPI, axis=1)
gs_df

# %%
gs_df.to_pickle("gs_df_with_raw_author_data.pkl")

# %%
gs_df = pd.read_pickle("gs_df_with_raw_author_data.pkl")

# %%
gs_df['raw_author_data'].isna().sum()
# Out:
# np.int64(41)

# %%
num_error_rows = gs_df['raw_author_data'].apply(lambda x: isinstance(x, dict) and 'error' in x).sum()
print(f"{num_error_rows} rows in gs_df have the key 'error' in the 'raw_author_data' column.")
# Out:
# 789 rows in gs_df have the key 'error' in the 'raw_author_data' column.

# %%
valid_results_df = gs_df[
    gs_df['raw_author_data'].apply(lambda x: isinstance(x, dict) and 'error' not in x)
]

print(f"{len(valid_results_df)} rows in gs_df contain valid results.")
valid_results_df
# Out:
# 98 rows in gs_df contain valid results.
#             ResponseId                                           DE13_1_1  \
# 2    R_4pD7OrlAt0l6mjL  https://scholar.google.com/citations?user=Guhy...
# 3    R_7OE9SfkJJ6q9jbP  https://scholar.google.com/citations?user=BSke...
# 23   R_2B4eUokwACUsT08  https://scholar.google.com/citations?user=DCWk...
# 27   R_2JTY94aJonph8Qx  https://scholar.google.it/citations?user=Uyrfi...
# 30   R_8S1zWLINCbSqU7z  https://scholar.google.com/citations?user=jqBv...
# ..                 ...                                                ...
# 359  R_2j7JL3u9Y8RgqTp  https://scholar.google.ro/citations?user=nvUh9...
# 361  R_8ebwm0zlzz0e45a  https://scholar.google.com/citations?user=ivVW...
# 363  R_2nMDwC92ug5uFyp  https://scholar.google.com/citations?user=dahp...
# 367  R_2LheWNSopaBNaL2  https://scholar.google.com/citations?user=vgb2...
# 374  R_8dL36M4ewu4PWGm  https://scholar.google.com/citations?user=jimO...
#
#           user_id                                    raw_author_data
# 2    GuhyORoAAAAJ  {'search_metadata': {'id': '68703f16634a638ac3...
# 3    BSkeONEAAAAJ  {'search_metadata': {'id': '68703f17874d50617c...
# 23   DCWkn9sAAAAJ  {'search_metadata': {'id': '68703f19abe7eca231...
# 27   UyrfibgAAAAJ  {'search_metadata': {'id': '68703f1b95e95031e3...
# 30   jqBvlqkAAAAJ  {'search_metadata': {'id': '68703f1e6f1e407892...
# ..            ...                                                ...
# 359  nvUh9U8AAAAJ  {'search_metadata': {'id': '6870401b895d905400...
# 361  ivVWglgAAAAJ  {'search_metadata': {'id': '6870401d2328e1d78f...
# 363  dahpSB8AAAAJ  {'search_metadata': {'id': '687040202f5ea04caf...
# 367  vgb2GJoAAAAJ  {'search_metadata': {'id': '68704022932b0e769b...
# 374  jimO8-cAAAAJ  {'search_metadata': {'id': '68704025a8dce67478...
#
# [98 rows x 4 columns]

# %%
import json 

first_entry = valid_results_df['raw_author_data'].iloc[0]
print(json.dumps(first_entry, indent=2))
# Out:
# {
#   "search_metadata": {
#     "id": "68703f16634a638ac302def0",
#     "status": "Success",
#     "json_endpoint": "https://serpapi.com/searches/cb1ba4b00edf9255/68703f16634a638ac302def0.json",
#     "created_at": "2025-07-10 22:30:46 UTC",
#     "processed_at": "2025-07-10 22:30:46 UTC",
#     "google_scholar_author_url": "https://scholar.google.com/citations?user=GuhyORoAAAAJ&hl=en",
#     "raw_html_file": "https://serpapi.com/searches/cb1ba4b00edf9255/68703f16634a638ac302def0.html",
#     "total_time_taken": 0.38
#   },
#   "search_parameters": {
#     "engine": "google_scholar_author",
#     "author_id": "GuhyORoAAAAJ",
#     "hl": "en"
#   },
#   "author": {
#     "name": "Symeon Papadopoulos",
#     "affiliations": "Information Technologies Institute (ITI)",
#     "email": "Verified email at iti.gr",
#     "website": "https://sites.google.com/site/sympapadopoulos/",
#     "interests": [
#       {
#         "title": "Artificial Intelligence",
#         "link": "https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:artificial_intelligence",
#         "serpapi_link": "https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aartificial_intelligence"
#       },
#       {
#         "title": "Media Verification",
#         "link": "https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:media_verification",
#         "serpapi_link": "https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amedia_verification"
#       },
#       {
#         "title": "AI Fairness",
#         "link": "https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:ai_fairness",
#         "serpapi_link": "https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aai_fairness"
#       },
#       {
#         "title": "Web Mining",
#         "link": "https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:web_mining",
#         "serpapi_link": "https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aweb_mining"
#       },
#       {
#         "title": "Multimedia Retrieval",
#         "link": "https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:multimedia_retrieval",
#         "serpapi_link": "https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amultimedia_retrieval"
#       }
#     ],
#     "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=view_photo&user=GuhyORoAAAAJ&citpid=4"
#   },
#   "articles": [
#     {
#       "title": "Bias in data\u2010driven artificial intelligence systems\u2014An introductory survey",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:gsN89kCJA0AC",
#       "citation_id": "GuhyORoAAAAJ:gsN89kCJA0AC",
#       "authors": "E Ntoutsi, P Fafalios, U Gadiraju, V Iosifidis, W Nejdl, ME Vidal, S Ruggieri, ...",
#       "publication": "Wiley Interdisciplinary Reviews: Data Mining and Knowledge Discovery 10 (3 \u2026, 2020",
#       "cited_by": {
#         "value": 1271,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13026498656506413474",
#         "serpapi_link": "https://serpapi.com/search.json?cites=13026498656506413474&engine=google_scholar&hl=en",
#         "cites_id": "13026498656506413474"
#       },
#       "year": "2020"
#     },
#     {
#       "title": "Community detection in Social Media: Performance and application considerations",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:mVmsd5A6BfQC",
#       "citation_id": "GuhyORoAAAAJ:mVmsd5A6BfQC",
#       "authors": "S Papadopoulos, Y Kompatsiaris, A Vakali, P Spyridonos",
#       "publication": "Data mining and knowledge discovery 24 (3), 515-554, 2012",
#       "cited_by": {
#         "value": 880,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3279730486504147065",
#         "serpapi_link": "https://serpapi.com/search.json?cites=3279730486504147065&engine=google_scholar&hl=en",
#         "cites_id": "3279730486504147065"
#       },
#       "year": "2012"
#     },
#     {
#       "title": "Sensing trending topics in Twitter",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:TQgYirikUcIC",
#       "citation_id": "GuhyORoAAAAJ:TQgYirikUcIC",
#       "authors": "LM Aiello, G Petkos, C Martin, D Corney, S Papadopoulos, R Skraba, ...",
#       "publication": "IEEE Transactions on multimedia 15 (6), 1268-1282, 2013",
#       "cited_by": {
#         "value": 579,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10582329977235029997",
#         "serpapi_link": "https://serpapi.com/search.json?cites=10582329977235029997&engine=google_scholar&hl=en",
#         "cites_id": "10582329977235029997"
#       },
#       "year": "2013"
#     },
#     {
#       "title": "Future directions for chatbot research: an interdisciplinary research agenda",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:bz8QjSJIRt4C",
#       "citation_id": "GuhyORoAAAAJ:bz8QjSJIRt4C",
#       "authors": "A F\u00f8lstad, T Araujo, ELC Law, PB Brandtzaeg, S Papadopoulos, L Reis, ...",
#       "publication": "Computing 103 (12), 2915-2942, 2021",
#       "cited_by": {
#         "value": 292,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6743383194194437236",
#         "serpapi_link": "https://serpapi.com/search.json?cites=6743383194194437236&engine=google_scholar&hl=en",
#         "cites_id": "6743383194194437236"
#       },
#       "year": "2021"
#     },
#     {
#       "title": "Verifying multimedia use at mediaeval 2015",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:K3LRdlH-MEoC",
#       "citation_id": "GuhyORoAAAAJ:K3LRdlH-MEoC",
#       "authors": "C Boididou, K Andreadou, S Papadopoulos, DT Dang Nguyen, G Boato, ...",
#       "publication": "MediaEval 2015 1436, 2015",
#       "cited_by": {
#         "value": 267,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17624468194496276143",
#         "serpapi_link": "https://serpapi.com/search.json?cites=17624468194496276143&engine=google_scholar&hl=en",
#         "cites_id": "17624468194496276143"
#       },
#       "year": "2015"
#     },
#     {
#       "title": "Detection and visualization of misleading content on Twitter",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:Fu2w8maKXqMC",
#       "citation_id": "GuhyORoAAAAJ:Fu2w8maKXqMC",
#       "authors": "C Boididou, S Papadopoulos, M Zampoglou, L Apostolidis, ...",
#       "publication": "International Journal of Multimedia Information Retrieval 7 (1), 71-86, 2018",
#       "cited_by": {
#         "value": 220,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6677663337427643016",
#         "serpapi_link": "https://serpapi.com/search.json?cites=6677663337427643016&engine=google_scholar&hl=en",
#         "cites_id": "6677663337427643016"
#       },
#       "year": "2018"
#     },
#     {
#       "title": "Adaptive sensitive reweighting to mitigate bias in fairness-aware classification",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:2KloaMYe4IUC",
#       "citation_id": "GuhyORoAAAAJ:2KloaMYe4IUC",
#       "authors": "E Krasanakis, E Spyromitros-Xioufis, S Papadopoulos, Y Kompatsiaris",
#       "publication": "Proceedings of the 2018 world wide web conference, 853-862, 2018",
#       "cited_by": {
#         "value": 205,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8518225860496267756",
#         "serpapi_link": "https://serpapi.com/search.json?cites=8518225860496267756&engine=google_scholar&hl=en",
#         "cites_id": "8518225860496267756"
#       },
#       "year": "2018"
#     },
#     {
#       "title": "Large-scale evaluation of splicing localization algorithms for web images",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:bnK-pcrLprsC",
#       "citation_id": "GuhyORoAAAAJ:bnK-pcrLprsC",
#       "authors": "M Zampoglou, S Papadopoulos, Y Kompatsiaris",
#       "publication": "Multimedia Tools and Applications 76 (4), 4801-4834, 2017",
#       "cited_by": {
#         "value": 203,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11992102513418250522",
#         "serpapi_link": "https://serpapi.com/search.json?cites=11992102513418250522&engine=google_scholar&hl=en",
#         "cites_id": "11992102513418250522"
#       },
#       "year": "2017"
#     },
#     {
#       "title": "Cluster-based landmark and event detection for tagged photo collections",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:9yKSN-GCB0IC",
#       "citation_id": "GuhyORoAAAAJ:9yKSN-GCB0IC",
#       "authors": "S Papadopoulos, C Zigkolis, Y Kompatsiaris, A Vakali",
#       "publication": "IEEE Multimedia Magazine 18 (1), 52-63, 2011",
#       "cited_by": {
#         "value": 192,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5769079025189879164",
#         "serpapi_link": "https://serpapi.com/search.json?cites=5769079025189879164&engine=google_scholar&hl=en",
#         "cites_id": "5769079025189879164"
#       },
#       "year": "2011"
#     },
#     {
#       "title": "Location extraction from social media: Geoparsing, location disambiguation, and geotagging",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:tzM49s52ZIMC",
#       "citation_id": "GuhyORoAAAAJ:tzM49s52ZIMC",
#       "authors": "SE Middleton, G Kordopatis-Zilos, S Papadopoulos, Y Kompatsiaris",
#       "publication": "ACM Transactions on Information Systems (TOIS) 36 (4), 1-27, 2018",
#       "cited_by": {
#         "value": 171,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10003099000455012494",
#         "serpapi_link": "https://serpapi.com/search.json?cites=10003099000455012494&engine=google_scholar&hl=en",
#         "cites_id": "10003099000455012494"
#       },
#       "year": "2018"
#     },
#     {
#       "title": "A survey on bias in visual datasets",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:rmuvC79q63oC",
#       "citation_id": "GuhyORoAAAAJ:rmuvC79q63oC",
#       "authors": "S Fabbrizzi, S Papadopoulos, E Ntoutsi, I Kompatsiaris",
#       "publication": "Computer Vision and Image Understanding 223, 103552, 2022",
#       "cited_by": {
#         "value": 167,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=973593936523816530",
#         "serpapi_link": "https://serpapi.com/search.json?cites=973593936523816530&engine=google_scholar&hl=en",
#         "cites_id": "973593936523816530"
#       },
#       "year": "2022"
#     },
#     {
#       "title": "A comprehensive study over VLAD and product quantization in large-scale image retrieval",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:70eg2SAEIzsC",
#       "citation_id": "GuhyORoAAAAJ:70eg2SAEIzsC",
#       "authors": "E Spyromitros-Xioufis, S Papadopoulos, IY Kompatsiaris, G Tsoumakas, ...",
#       "publication": "IEEE Transactions on Multimedia 16 (6), 1713-1728, 2014",
#       "cited_by": {
#         "value": 163,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8828017932860594373",
#         "serpapi_link": "https://serpapi.com/search.json?cites=8828017932860594373&engine=google_scholar&hl=en",
#         "cites_id": "8828017932860594373"
#       },
#       "year": "2014"
#     },
#     {
#       "title": "Towards content-oriented patent document processing",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:u5HHmVD_uO8C",
#       "citation_id": "GuhyORoAAAAJ:u5HHmVD_uO8C",
#       "authors": "L Wanner, R Baeza-Yates, S Br\u00fcgmann, J Codina, B Diallo, E Escorsa, ...",
#       "publication": "World Patent Information 30 (1), 21-33, 2008",
#       "cited_by": {
#         "value": 126,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9883817991412099544",
#         "serpapi_link": "https://serpapi.com/search.json?cites=9883817991412099544&engine=google_scholar&hl=en",
#         "cites_id": "9883817991412099544"
#       },
#       "year": "2008"
#     },
#     {
#       "title": "Challenges of computational verification in social multimedia",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:ns9cj8rnVeAC",
#       "citation_id": "GuhyORoAAAAJ:ns9cj8rnVeAC",
#       "authors": "C Boididou, S Papadopoulos, Y Kompatsiaris, S Schifferes, N Newman",
#       "publication": "Proceedings of the 23rd international conference on world wide web, 743-748, 2014",
#       "cited_by": {
#         "value": 124,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17290471333845990582",
#         "serpapi_link": "https://serpapi.com/search.json?cites=17290471333845990582&engine=google_scholar&hl=en",
#         "cites_id": "17290471333845990582"
#       },
#       "year": "2014"
#     },
#     {
#       "title": "Detecting image splicing in the wild (web)",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:u9iWguZQMMsC",
#       "citation_id": "GuhyORoAAAAJ:u9iWguZQMMsC",
#       "authors": "M Zampoglou, S Papadopoulos, Y Kompatsiaris",
#       "publication": "2015 IEEE international conference on multimedia & expo workshops (ICMEW), 1-6, 2015",
#       "cited_by": {
#         "value": 117,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7061353514933499059",
#         "serpapi_link": "https://serpapi.com/search.json?cites=7061353514933499059&engine=google_scholar&hl=en",
#         "cites_id": "7061353514933499059"
#       },
#       "year": "2015"
#     },
#     {
#       "title": "Social event detection using multimodal clustering and integrating supervisory signals",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:ZeXyd9-uunAC",
#       "citation_id": "GuhyORoAAAAJ:ZeXyd9-uunAC",
#       "authors": "G Petkos, S Papadopoulos, Y Kompatsiaris",
#       "publication": "Proceedings of the 2nd ACM International Conference on Multimedia Retrieval, 1-8, 2012",
#       "cited_by": {
#         "value": 109,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5703854394753136390",
#         "serpapi_link": "https://serpapi.com/search.json?cites=5703854394753136390&engine=google_scholar&hl=en",
#         "cites_id": "5703854394753136390"
#       },
#       "year": "2012"
#     },
#     {
#       "title": "Predicting elections for multiple countries using Twitter and polls",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:bFI3QPDXJZMC",
#       "citation_id": "GuhyORoAAAAJ:bFI3QPDXJZMC",
#       "authors": "A Tsakalidis, S Papadopoulos, AI Cristea, Y Kompatsiaris",
#       "publication": "IEEE Intelligent Systems 30 (2), 10-17, 2015",
#       "cited_by": {
#         "value": 108,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=696365308204791837,17448840658362568453",
#         "serpapi_link": "https://serpapi.com/search.json?cites=696365308204791837%2C17448840658362568453&engine=google_scholar&hl=en",
#         "cites_id": "696365308204791837,17448840658362568453"
#       },
#       "year": "2015"
#     },
#     {
#       "title": "Visil: Fine-grained spatio-temporal video similarity learning",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:BUYA1_V_uYcC",
#       "citation_id": "GuhyORoAAAAJ:BUYA1_V_uYcC",
#       "authors": "G Kordopatis-Zilos, S Papadopoulos, I Patras, I Kompatsiaris",
#       "publication": "Proceedings of the IEEE/CVF international conference on computer vision \u2026, 2019",
#       "cited_by": {
#         "value": 101,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8951545811351674783",
#         "serpapi_link": "https://serpapi.com/search.json?cites=8951545811351674783&engine=google_scholar&hl=en",
#         "cites_id": "8951545811351674783"
#       },
#       "year": "2019"
#     },
#     {
#       "title": "Near-duplicate video retrieval with deep metric learning",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:PR6Y55bgFSsC",
#       "citation_id": "GuhyORoAAAAJ:PR6Y55bgFSsC",
#       "authors": "G Kordopatis-Zilos, S Papadopoulos, I Patras, Y Kompatsiaris",
#       "publication": "Proceedings of the IEEE international conference on computer vision \u2026, 2017",
#       "cited_by": {
#         "value": 97,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15365803913047513091",
#         "serpapi_link": "https://serpapi.com/search.json?cites=15365803913047513091&engine=google_scholar&hl=en",
#         "cites_id": "15365803913047513091"
#       },
#       "year": "2017"
#     },
#     {
#       "title": "Towards content-based patent image retrieval: A framework perspective",
#       "link": "https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:2osOgNQ5qMEC",
#       "citation_id": "GuhyORoAAAAJ:2osOgNQ5qMEC",
#       "authors": "S Vrochidis, S Papadopoulos, A Moumtzidou, P Sidiropoulos, E Pianta, ...",
#       "publication": "World Patent Information 32 (2), 94-106, 2010",
#       "cited_by": {
#         "value": 97,
#         "link": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8986974149628038772,14595671069861555482",
#         "serpapi_link": "https://serpapi.com/search.json?cites=8986974149628038772%2C14595671069861555482&engine=google_scholar&hl=en",
#         "cites_id": "8986974149628038772,14595671069861555482"
#       },
#       "year": "2010"
#     }
#   ],
#   "cited_by": {
#     "table": [
#       {
#         "citations": {
#           "all": 9654,
#           "since_2020": 6068
#         }
#       },
#       {
#         "h_index": {
#           "all": 44,
#           "since_2020": 34
#         }
#       },
#       {
#         "i10_index": {
#           "all": 144,
#           "since_2020": 99
#         }
#       }
#     ],
#     "graph": [
#       {
#         "year": 2009,
#         "citations": 28
#       },
#       {
#         "year": 2010,
#         "citations": 44
#       },
#       {
#         "year": 2011,
#         "citations": 116
#       },
#       {
#         "year": 2012,
#         "citations": 120
#       },
#       {
#         "year": 2013,
#         "citations": 215
#       },
#       {
#         "year": 2014,
#         "citations": 303
#       },
#       {
#         "year": 2015,
#         "citations": 424
#       },
#       {
#         "year": 2016,
#         "citations": 456
#       },
#       {
#         "year": 2017,
#         "citations": 531
#       },
#       {
#         "year": 2018,
#         "citations": 581
#       },
#       {
#         "year": 2019,
#         "citations": 644
#       },
#       {
#         "year": 2020,
#         "citations": 705
#       },
#       {
#         "year": 2021,
#         "citations": 778
#       },
#       {
#         "year": 2022,
#         "citations": 978
#       },
#       {
#         "year": 2023,
#         "citations": 1154
#       },
#       {
#         "year": 2024,
#         "citations": 1534
#       },
#       {
#         "year": 2025,
#         "citations": 899
#       }
#     ]
#   },
#   "public_access": {
#     "link": "https://scholar.google.com/citations?view_op=list_mandates&hl=en&user=GuhyORoAAAAJ",
#     "available": 114,
#     "not_available": 1
#   },
#   "co_authors": [
#     {
#       "name": "Ioannis (Yiannis) Kompatsiaris",
#       "link": "https://scholar.google.com/citations?user=Nr7smP8AAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=Nr7smP8AAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "Nr7smP8AAAAJ",
#       "affiliations": "Director, Information Technologies Institute, CERTH",
#       "email": "Verified email at iti.gr",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=Nr7smP8AAAAJ&citpid=3"
#     },
#     {
#       "name": "Giorgos Kordopatis-Zilos",
#       "link": "https://scholar.google.com/citations?user=Do-7qx4AAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=Do-7qx4AAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "Do-7qx4AAAAJ",
#       "affiliations": "Czech Technical University in Prague",
#       "email": "Verified email at fel.cvut.cz",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=Do-7qx4AAAAJ&citpid=2"
#     },
#     {
#       "name": "Emmanouil Krasanakis",
#       "link": "https://scholar.google.com/citations?user=o0YkL-sAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=o0YkL-sAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "o0YkL-sAAAAJ",
#       "affiliations": "PostDoc reseacher, CERTH-ITI",
#       "email": "Verified email at iti.gr",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=o0YkL-sAAAAJ&citpid=2"
#     },
#     {
#       "name": "Georgios Petkos",
#       "link": "https://scholar.google.com/citations?user=i6aGLkcAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=i6aGLkcAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "i6aGLkcAAAAJ",
#       "affiliations": "CERTH-ITI",
#       "email": "Verified email at iti.gr",
#       "thumbnail": "https://scholar.google.com/citations/images/avatar_scholar_56.png"
#     },
#     {
#       "name": "Athena Vakali",
#       "link": "https://scholar.google.com/citations?user=sq_u8P0AAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=sq_u8P0AAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "sq_u8P0AAAAJ",
#       "affiliations": "Professor of Computer Science, Aristotle University",
#       "email": "Verified email at csd.auth.gr",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=sq_u8P0AAAAJ&citpid=4"
#     },
#     {
#       "name": "Christos Koutlis",
#       "link": "https://scholar.google.com/citations?user=mFQe8uQAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=mFQe8uQAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "mFQe8uQAAAAJ",
#       "affiliations": "Postdoctoral Researcher, Information Technologies Institute, CERTH",
#       "email": "Verified email at iti.gr",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=mFQe8uQAAAAJ&citpid=1"
#     },
#     {
#       "name": "Markos Zampoglou",
#       "link": "https://scholar.google.com/citations?user=YNFYlTgAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=YNFYlTgAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "YNFYlTgAAAAJ",
#       "affiliations": "University of the Aegean",
#       "email": "Verified email at aegean.gr",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=YNFYlTgAAAAJ&citpid=2"
#     },
#     {
#       "name": "Manos Schinas",
#       "link": "https://scholar.google.com/citations?user=gsErSxAAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=gsErSxAAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "gsErSxAAAAAJ",
#       "affiliations": "Information Technologies Institute, CERTH",
#       "email": "Verified email at iti.gr",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=gsErSxAAAAAJ&citpid=1"
#     },
#     {
#       "name": "Eleftherios Spyromitros-Xioufis",
#       "link": "https://scholar.google.com/citations?user=DnF3UEUAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=DnF3UEUAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "DnF3UEUAAAAJ",
#       "affiliations": "Machine Learning Scientist, Expedia Group",
#       "email": "Verified email at expediagroup.com",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=DnF3UEUAAAAJ&citpid=3"
#     },
#     {
#       "name": "Eirini Ntoutsi",
#       "link": "https://scholar.google.com/citations?user=RdA9uxYAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=RdA9uxYAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "RdA9uxYAAAAJ",
#       "affiliations": "Professor of Open Source Intelligence at the Bundeswehr University Munich, RI CODE, L3S",
#       "email": "Verified email at unibw.de",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=RdA9uxYAAAAJ&citpid=5"
#     },
#     {
#       "name": "Olga Papadopoulou",
#       "link": "https://scholar.google.com/citations?user=kd-2aqYAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=kd-2aqYAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "kd-2aqYAAAAJ",
#       "affiliations": "CERTH-ITI",
#       "email": "Verified email at iti.gr",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=kd-2aqYAAAAJ&citpid=1"
#     },
#     {
#       "name": "Vasileios Mezaris",
#       "link": "https://scholar.google.com/citations?user=252ni8gAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=252ni8gAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "252ni8gAAAAJ",
#       "affiliations": "Research Director at CERTH-ITI",
#       "email": "Verified email at iti.gr",
#       "thumbnail": "https://scholar.google.com/citations/images/avatar_scholar_56.png"
#     },
#     {
#       "name": "Adrian Popescu",
#       "link": "https://scholar.google.com/citations?user=fjsa2GYAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=fjsa2GYAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "fjsa2GYAAAAJ",
#       "affiliations": "CEA LIST, France",
#       "email": "Verified email at cea.fr",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=fjsa2GYAAAAJ&citpid=2"
#     },
#     {
#       "name": "Ioannis Patras",
#       "link": "https://scholar.google.com/citations?user=OBYLxRkAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=OBYLxRkAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "OBYLxRkAAAAJ",
#       "affiliations": "Professor, Queen Mary, University of London",
#       "email": "Verified email at eecs.qmul.ac.uk",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=OBYLxRkAAAAJ&citpid=8"
#     },
#     {
#       "name": "Stefanos Vrochidis",
#       "link": "https://scholar.google.com/citations?user=etxB_s0AAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=etxB_s0AAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "etxB_s0AAAAJ",
#       "affiliations": "Information Technologies Institute - Centre for Research and Technology Hellas",
#       "email": "Verified email at iti.gr",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=etxB_s0AAAAJ&citpid=1"
#     },
#     {
#       "name": "Luca Maria Aiello",
#       "link": "https://scholar.google.com/citations?user=FIX-7hcAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=FIX-7hcAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "FIX-7hcAAAAJ",
#       "affiliations": "IT University of Copenhagen",
#       "email": "Verified email at itu.dk",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=FIX-7hcAAAAJ&citpid=4"
#     },
#     {
#       "name": "Christos Zigkolis",
#       "link": "https://scholar.google.com/citations?user=6qfSjVwAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=6qfSjVwAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "6qfSjVwAAAAJ",
#       "affiliations": "Department of Informatics AUTH",
#       "email": "Verified email at csd.auth.gr",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=6qfSjVwAAAAJ&citpid=4"
#     },
#     {
#       "name": "Stefanos-Iordanis Papadopoulos",
#       "link": "https://scholar.google.com/citations?user=ZSFB6vcAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=ZSFB6vcAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "ZSFB6vcAAAAJ",
#       "affiliations": "PhD candidate at ECE-AUTh, Research Associate at ITI-CERTH",
#       "email": "Verified email at iti.gr",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=ZSFB6vcAAAAJ&citpid=1"
#     },
#     {
#       "name": "Petter Bae Brandtzaeg",
#       "link": "https://scholar.google.com/citations?user=lOSmypYAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=lOSmypYAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "lOSmypYAAAAJ",
#       "affiliations": "Professor at Department of Media and Communication, @UniversityofOslo & @SINTEF",
#       "email": "Verified email at uio.no",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=lOSmypYAAAAJ&citpid=3"
#     },
#     {
#       "name": "Ewa Luger",
#       "link": "https://scholar.google.com/citations?user=vzkTn_cAAAAJ&hl=en",
#       "serpapi_link": "https://serpapi.com/search.json?author_id=vzkTn_cAAAAJ&engine=google_scholar_author&hl=en",
#       "author_id": "vzkTn_cAAAAJ",
#       "affiliations": "Chair of Human-Data Interaction, University of Edinburgh",
#       "email": "Verified email at exseed.ed.ac.uk",
#       "thumbnail": "https://scholar.googleusercontent.com/citations?view_op=small_photo&user=vzkTn_cAAAAJ&citpid=3"
#     }
#   ],
#   "serpapi_pagination": {
#     "next": "https://serpapi.com/search.json?author_id=GuhyORoAAAAJ&engine=google_scholar_author&hl=en&start=20"
#   }
# }

# %%
first_entry.keys()
# Out:
# dict_keys(['search_metadata', 'search_parameters', 'author', 'articles', 'cited_by', 'public_access', 'co_authors', 'serpapi_pagination'])

# %%
first_entry['serpapi_pagination'].get('next')
# Out:
# 'https://serpapi.com/search.json?author_id=GuhyORoAAAAJ&engine=google_scholar_author&hl=en&start=20'

# %%
first_entry['cited_by'].keys()
# Out:
# dict_keys(['table', 'graph'])

# %%
first_entry['cited_by']
# Out:
# {'table': [{'citations': {'all': 9654, 'since_2020': 6068}},
#   {'h_index': {'all': 44, 'since_2020': 34}},
#   {'i10_index': {'all': 144, 'since_2020': 99}}],
#  'graph': [{'year': 2009, 'citations': 28},
#   {'year': 2010, 'citations': 44},
#   {'year': 2011, 'citations': 116},
#   {'year': 2012, 'citations': 120},
#   {'year': 2013, 'citations': 215},
#   {'year': 2014, 'citations': 303},
#   {'year': 2015, 'citations': 424},
#   {'year': 2016, 'citations': 456},
#   {'year': 2017, 'citations': 531},
#   {'year': 2018, 'citations': 581},
#   {'year': 2019, 'citations': 644},
#   {'year': 2020, 'citations': 705},
#   {'year': 2021, 'citations': 778},
#   {'year': 2022, 'citations': 978},
#   {'year': 2023, 'citations': 1154},
#   {'year': 2024, 'citations': 1534},
#   {'year': 2025, 'citations': 899}]}

# %%
first_entry['author']
# Out:
# {'name': 'Symeon Papadopoulos',
#  'affiliations': 'Information Technologies Institute (ITI)',
#  'email': 'Verified email at iti.gr',
#  'website': 'https://sites.google.com/site/sympapadopoulos/',
#  'interests': [{'title': 'Artificial Intelligence',
#    'link': 'https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:artificial_intelligence',
#    'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aartificial_intelligence'},
#   {'title': 'Media Verification',
#    'link': 'https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:media_verification',
#    'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amedia_verification'},
#   {'title': 'AI Fairness',
#    'link': 'https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:ai_fairness',
#    'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aai_fairness'},
#   {'title': 'Web Mining',
#    'link': 'https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:web_mining',
#    'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aweb_mining'},
#   {'title': 'Multimedia Retrieval',
#    'link': 'https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:multimedia_retrieval',
#    'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amultimedia_retrieval'}],
#  'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=view_photo&user=GuhyORoAAAAJ&citpid=4'}

# %%
first_entry["articles"][0]
# Out:
# {'title': 'Bias in data‐driven artificial intelligence systems—An introductory survey',
#  'link': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=GuhyORoAAAAJ&citation_for_view=GuhyORoAAAAJ:gsN89kCJA0AC',
#  'citation_id': 'GuhyORoAAAAJ:gsN89kCJA0AC',
#  'authors': 'E Ntoutsi, P Fafalios, U Gadiraju, V Iosifidis, W Nejdl, ME Vidal, S Ruggieri, ...',
#  'publication': 'Wiley Interdisciplinary Reviews: Data Mining and Knowledge Discovery 10 (3 …, 2020',
#  'cited_by': {'value': 1271,
#   'link': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13026498656506413474',
#   'serpapi_link': 'https://serpapi.com/search.json?cites=13026498656506413474&engine=google_scholar&hl=en',
#   'cites_id': '13026498656506413474'},
#  'year': '2020'}

# %%
articles = first_entry['articles']

# %%
import pandas as pd

# Flatten key fields into a list of dicts
records = []
for article in first_entry['articles']:
    records.append({
        'title': article.get('title'),
        'year': article.get('year'),
        'cited_by': article.get('cited_by', {}).get('value'),
        'publication': article.get('publication'),
        'authors': article.get('authors'),
        'citation_id': article.get('citation_id')
    })

df_articles = pd.DataFrame(records)

# %%
df_articles
# Out:
#                                                 title  year  cited_by  \
# 0   Bias in data‐driven artificial intelligence sy...  2020      1271
# 1   Community detection in Social Media: Performan...  2012       880
# 2                  Sensing trending topics in Twitter  2013       579
# 3   Future directions for chatbot research: an int...  2021       292
# 4          Verifying multimedia use at mediaeval 2015  2015       267
# 5   Detection and visualization of misleading cont...  2018       220
# 6   Adaptive sensitive reweighting to mitigate bia...  2018       205
# 7   Large-scale evaluation of splicing localizatio...  2017       203
# 8   Cluster-based landmark and event detection for...  2011       192
# 9   Location extraction from social media: Geopars...  2018       171
# 10                A survey on bias in visual datasets  2022       167
# 11  A comprehensive study over VLAD and product qu...  2014       163
# 12  Towards content-oriented patent document proce...  2008       126
# 13  Challenges of computational verification in so...  2014       124
# 14         Detecting image splicing in the wild (web)  2015       117
# 15  Social event detection using multimodal cluste...  2012       109
# 16  Predicting elections for multiple countries us...  2015       108
# 17  Visil: Fine-grained spatio-temporal video simi...  2019       101
# 18  Near-duplicate video retrieval with deep metri...  2017        97
# 19  Towards content-based patent image retrieval: ...  2010        97
#
#                                           publication  \
# 0   Wiley Interdisciplinary Reviews: Data Mining a...
# 1   Data mining and knowledge discovery 24 (3), 51...
# 2   IEEE Transactions on multimedia 15 (6), 1268-1...
# 3                 Computing 103 (12), 2915-2942, 2021
# 4                           MediaEval 2015 1436, 2015
# 5   International Journal of Multimedia Informatio...
# 6   Proceedings of the 2018 world wide web confere...
# 7   Multimedia Tools and Applications 76 (4), 4801...
# 8        IEEE Multimedia Magazine 18 (1), 52-63, 2011
# 9   ACM Transactions on Information Systems (TOIS)...
# 10  Computer Vision and Image Understanding 223, 1...
# 11  IEEE Transactions on Multimedia 16 (6), 1713-1...
# 12       World Patent Information 30 (1), 21-33, 2008
# 13  Proceedings of the 23rd international conferen...
# 14  2015 IEEE international conference on multimed...
# 15  Proceedings of the 2nd ACM International Confe...
# 16       IEEE Intelligent Systems 30 (2), 10-17, 2015
# 17  Proceedings of the IEEE/CVF international conf...
# 18  Proceedings of the IEEE international conferen...
# 19      World Patent Information 32 (2), 94-106, 2010
#
#                                               authors  \
# 0   E Ntoutsi, P Fafalios, U Gadiraju, V Iosifidis...
# 1   S Papadopoulos, Y Kompatsiaris, A Vakali, P Sp...
# 2   LM Aiello, G Petkos, C Martin, D Corney, S Pap...
# 3   A Følstad, T Araujo, ELC Law, PB Brandtzaeg, S...
# 4   C Boididou, K Andreadou, S Papadopoulos, DT Da...
# 5   C Boididou, S Papadopoulos, M Zampoglou, L Apo...
# 6   E Krasanakis, E Spyromitros-Xioufis, S Papadop...
# 7         M Zampoglou, S Papadopoulos, Y Kompatsiaris
# 8   S Papadopoulos, C Zigkolis, Y Kompatsiaris, A ...
# 9   SE Middleton, G Kordopatis-Zilos, S Papadopoul...
# 10  S Fabbrizzi, S Papadopoulos, E Ntoutsi, I Komp...
# 11  E Spyromitros-Xioufis, S Papadopoulos, IY Komp...
# 12  L Wanner, R Baeza-Yates, S Brügmann, J Codina,...
# 13  C Boididou, S Papadopoulos, Y Kompatsiaris, S ...
# 14        M Zampoglou, S Papadopoulos, Y Kompatsiaris
# 15           G Petkos, S Papadopoulos, Y Kompatsiaris
# 16  A Tsakalidis, S Papadopoulos, AI Cristea, Y Ko...
# 17  G Kordopatis-Zilos, S Papadopoulos, I Patras, ...
# 18  G Kordopatis-Zilos, S Papadopoulos, I Patras, ...
# 19  S Vrochidis, S Papadopoulos, A Moumtzidou, P S...
#
#                   citation_id
# 0   GuhyORoAAAAJ:gsN89kCJA0AC
# 1   GuhyORoAAAAJ:mVmsd5A6BfQC
# 2   GuhyORoAAAAJ:TQgYirikUcIC
# 3   GuhyORoAAAAJ:bz8QjSJIRt4C
# 4   GuhyORoAAAAJ:K3LRdlH-MEoC
# 5   GuhyORoAAAAJ:Fu2w8maKXqMC
# 6   GuhyORoAAAAJ:2KloaMYe4IUC
# 7   GuhyORoAAAAJ:bnK-pcrLprsC
# 8   GuhyORoAAAAJ:9yKSN-GCB0IC
# 9   GuhyORoAAAAJ:tzM49s52ZIMC
# 10  GuhyORoAAAAJ:rmuvC79q63oC
# 11  GuhyORoAAAAJ:70eg2SAEIzsC
# 12  GuhyORoAAAAJ:u5HHmVD_uO8C
# 13  GuhyORoAAAAJ:ns9cj8rnVeAC
# 14  GuhyORoAAAAJ:u9iWguZQMMsC
# 15  GuhyORoAAAAJ:ZeXyd9-uunAC
# 16  GuhyORoAAAAJ:bFI3QPDXJZMC
# 17  GuhyORoAAAAJ:BUYA1_V_uYcC
# 18  GuhyORoAAAAJ:PR6Y55bgFSsC
# 19  GuhyORoAAAAJ:2osOgNQ5qMEC

# %% [markdown]
# I need to scrape again, and get the full paginated publication history of researchers. Therefore, I need to use another code than the one I have used, as the one I used retrieves by default only the first 20 articles.

# %%
import requests

def fetch_articles_and_citations(user_id, api_key):
    total_requests = 0
    url = "https://serpapi.com/search"
    params = {
        "engine": "google_scholar_author",
        "author_id": user_id,
        "api_key": api_key,
        "num": 100  # up to 100 articles per page
    }

    articles = []
    start = 0
    cited_by_info = None  # This will hold the full `cited_by` block
    author_metadata = None

    while True:
        params["start"] = start
        response = requests.get(url, params=params)
        data = response.json()
        total_requests += 1

        # Error handling
        if 'error' in data:
            print(f"[!] Error for user_id {user_id}: {data['error']}")
            break

        # Extract full cited_by block from first page
        if cited_by_info is None and 'cited_by' in data:
            cited_by_info = data['cited_by']

        if author_metadata is None and 'author' in data:
            author_metadata = data['author']

        # Collect article metadata
        new_articles = data.get("articles", [])
        if not new_articles:
            break

        articles.extend(new_articles)
        start += len(new_articles)

        # If fewer than requested, we are done
        if len(new_articles) < 100:
            break

    return {
        "articles": articles,
        "cited_by": cited_by_info,  # Full cited_by dict (includes graph, h_index, table, etc.)
        "author": author_metadata,
        "requests_made": total_requests
    }

# %%
def load_api_key(filepath="/Users/Paula_1/Desktop/Parenthood/scrape_googlescholar/serpapi.txt"):  # another: serapi.txt):
    with open(filepath, "r") as f:
        return f.read().strip()

# %%
api_key = load_api_key()

# %%
# I will try with the first 5 user_ids in gs_df

for col in ['full_articles', 'cited_by', 'citation_graph']:
    if col not in valid_results_df.columns:
        valid_results_df[col] = None
    valid_results_df[col] = valid_results_df[col].astype(object)

total_requests = 0

# Loop through first 5 entries
for idx in valid_results_df.head(5).index:
    if pd.notna(valid_results_df.at[idx, 'user_id']):
        needs_articles = valid_results_df.at[idx, 'full_articles'] is None
        needs_citation_graph = valid_results_df.at[idx, 'cited_by'] is None

        if needs_articles or needs_citation_graph:
            result = fetch_articles_and_citations(
                valid_results_df.at[idx, 'user_id'], api_key
            )

            if needs_articles:
                valid_results_df.at[idx, 'full_articles'] = result['articles']

            if needs_citation_graph:
                cited_by = result.get('cited_by', {})
                valid_results_df.at[idx, 'citation_graph'] = cited_by.get('graph', [])
                valid_results_df.at[idx, 'cited_by'] = cited_by

            total_requests += result.get('requests_made', 0)

print(f"Total requests made: {total_requests}")
# Out:
# /var/folders/4n/x6xrnlyj6nngzc77qzc7h4f40000gn/T/ipykernel_76489/4083264825.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_results_df[col] = valid_results_df[col].astype(object)
# /var/folders/4n/x6xrnlyj6nngzc77qzc7h4f40000gn/T/ipykernel_76489/4083264825.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_results_df[col] = valid_results_df[col].astype(object)
# /var/folders/4n/x6xrnlyj6nngzc77qzc7h4f40000gn/T/ipykernel_76489/4083264825.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_results_df[col] = valid_results_df[col].astype(object)
# Total requests made: 11

# %%
valid_results_df.head(5)
# Out:
#            ResponseId                                           DE13_1_1  \
# 2   R_4pD7OrlAt0l6mjL  https://scholar.google.com/citations?user=Guhy...
# 3   R_7OE9SfkJJ6q9jbP  https://scholar.google.com/citations?user=BSke...
# 23  R_2B4eUokwACUsT08  https://scholar.google.com/citations?user=DCWk...
# 27  R_2JTY94aJonph8Qx  https://scholar.google.it/citations?user=Uyrfi...
# 30  R_8S1zWLINCbSqU7z  https://scholar.google.com/citations?user=jqBv...
#
#          user_id                                    raw_author_data  \
# 2   GuhyORoAAAAJ  {'search_metadata': {'id': '68703f16634a638ac3...
# 3   BSkeONEAAAAJ  {'search_metadata': {'id': '68703f17874d50617c...
# 23  DCWkn9sAAAAJ  {'search_metadata': {'id': '68703f19abe7eca231...
# 27  UyrfibgAAAAJ  {'search_metadata': {'id': '68703f1b95e95031e3...
# 30  jqBvlqkAAAAJ  {'search_metadata': {'id': '68703f1e6f1e407892...
#
#                                         full_articles  \
# 2   [{'title': 'Bias in data‐driven artificial int...
# 3   [{'title': 'GDPR Interference With Next Genera...
# 23  [{'title': 'Ecological impact of introduced fi...
# 27  [{'title': 'Agent based modeling and simulatio...
# 30  [{'title': 'Injectable and biodegradable hydro...
#
#                                              cited_by  \
# 2   {'table': [{'citations': {'all': 9691, 'since_...
# 3   {'table': [{'citations': {'all': 45, 'since_20...
# 23  {'table': [{'citations': {'all': 1169, 'since_...
# 27  {'table': [{'citations': {'all': 4113, 'since_...
# 30  {'table': [{'citations': {'all': 7777, 'since_...
#
#                                        citation_graph
# 2   [{'year': 2009, 'citations': 28}, {'year': 201...
# 3   [{'year': 2020, 'citations': 3}, {'year': 2021...
# 23  [{'year': 2011, 'citations': 7}, {'year': 2012...
# 27  [{'year': 2004, 'citations': 28}, {'year': 200...
# 30  [{'year': 2006, 'citations': 25}, {'year': 200...

# %%
# I want to observe how many articles the first 5 researchers have on google scholar
subset = gs_df[gs_df['full_articles'].notna()].head(5).copy()

subset['num_articles'] = subset['full_articles'].apply(
    lambda x: len(x) if isinstance(x, list) else 0
)

subset[['user_id', 'num_articles']]
# Out:
#          user_id  num_articles
# 2   GuhyORoAAAAJ           338
# 3   BSkeONEAAAAJ            10
# 23  DCWkn9sAAAAJ            66
# 27  UyrfibgAAAAJ           295

# %% [markdown]
# To minimize the requests to send down to those user_ids that also provided information on there number of children and parental leave take, I will add these cols into the gs_df, and filter/scrape by those.

# %%
import pandas as pd

raw_df = pd.read_excel("../../../data/original_raw_data/Parenthood in Academia_November 7, 2024_15.52.xlsx")
raw_df.head()
# Out:
# /Users/Paula_1/opt/anaconda3/envs/parenthood/lib/python3.13/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#              StartDate              EndDate         Status  Progress  \
# 0           Start Date             End Date  Response Type  Progress
# 1  2024-03-25 15:45:50  2024-03-25 15:58:19              0       100
# 2  2024-03-26 17:00:29  2024-03-26 17:17:43              0       100
# 3  2024-03-29 16:09:27  2024-03-29 16:39:04              0       100
# 4  2024-04-16 12:45:38  2024-04-16 12:55:21              0       100
#
#    Duration (in seconds)  Finished                RecordedDate  \
# 0  Duration (in seconds)  Finished               Recorded Date
# 1                    748         1  2024-03-25 15:58:20.398000
# 2                   1034         1  2024-03-26 17:17:44.908000
# 3                   1777         1  2024-03-29 16:39:07.534000
# 4                    583         1  2024-04-16 12:55:22.733000
#
#           ResponseId   DistributionChannel   UserLanguage  ...  \
# 0        Response ID  Distribution Channel  User Language  ...
# 1  R_2jpMi7QsRScengv                 email             EN  ...
# 2  R_4ScOupmxBzBk7dL                 email             EN  ...
# 3  R_77h3lBm8zYTS5a1                 email             EN  ...
# 4  R_2V4kjf4gOQNH6EL             anonymous             EN  ...
#
#                                                  LA2  \
# 0  How would you estimate the percentage of women...
# 1                                                NaN
# 2                                                NaN
# 3                                                  3
# 4                                                  4
#
#                                      LA3  \
# 0  Have you considered leaving academia?
# 1                                    NaN
# 2                                    NaN
# 3                                      3
# 4                                      4
#
#                                                 LA4a  \
# 0  Please briefly elaborate on your reasons for c...
# 1                                                NaN
# 2                                                NaN
# 3  The path demands significant sacrifices, espec...
# 4                                                NaN
#
#                                                 LA4b  \
# 0  Please briefly elaborate on your reasons for l...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                   C1  \
# 0  How did you hear about this survey? - Selected...
# 1                                                NaN
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#                                            C1_3_TEXT  \
# 0  How did you hear about this survey? - Social m...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            C1_4_TEXT  \
# 0  How did you hear about this survey? - Mailing ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            C1_5_TEXT  \
# 0  How did you hear about this survey? - Other (p...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                   C2  gender
# 0  Do you have any other comments related to this...  gender
# 1                                                NaN   Woman
# 2                                                NaN     Man
# 3  The questions about # of papers expected or pr...   Woman
# 4                                                NaN   Woman
#
# [5 rows x 317 columns]

# %%
cols_to_add = ["ResponseId", "DE22", "PL6_1", "PL6_2", "DE23_1_2"]
selected_cols = raw_df[cols_to_add]

gs_df = gs_df.merge(selected_cols, how='left', on='ResponseId')

# %%
gs_df
# Out:
#             ResponseId                                           DE13_1_1  \
# 0    R_4pD7OrlAt0l6mjL  https://scholar.google.com/citations?user=Guhy...
# 1    R_7OE9SfkJJ6q9jbP  https://scholar.google.com/citations?user=BSke...
# 2    R_62ojVyfY2SdzKN0  https://scholar.google.com/scholar?hl=en&as_sd...
# 3    R_2B4eUokwACUsT08  https://scholar.google.com/citations?user=DCWk...
# 4    R_2JTY94aJonph8Qx  https://scholar.google.it/citations?user=Uyrfi...
# ..                 ...                                                ...
# 923  R_8oUd1CmnYTMewcw  https://scholar.google.com/citations?user=Q4_A...
# 924  R_8PXnvStEzBAgC8m  https://scholar.google.com/citations?user=AMLe...
# 925  R_2sTEG4FLmmU8kOm  https://www.webofscience.com/wos/woscc/basic-s...
# 926  R_2w60Oo6hzaQimqC  https://scholar.google.co.uk/citations?user=Wi...
# 927  R_2iFjsLGZX3qEgu0  https://scholar.google.com/citations?hl=en&use...
#
#           user_id                                    raw_author_data DE22  \
# 0    GuhyORoAAAAJ  {'search_metadata': {'id': '68703f16634a638ac3...    2
# 1    BSkeONEAAAAJ  {'search_metadata': {'id': '68703f17874d50617c...    0
# 2            None                                               None    2
# 3    DCWkn9sAAAAJ  {'search_metadata': {'id': '68703f19abe7eca231...    1
# 4    UyrfibgAAAAJ  {'search_metadata': {'id': '68703f1b95e95031e3...    1
# ..            ...                                                ...  ...
# 923  Q4_AHDYAAAAJ  {'error': 'Your account has run out of searche...    1
# 924  AMLeN5MAAAAJ  {'error': 'Your account has run out of searche...    0
# 925          None                                               None    3
# 926  WiW_7VkAAAAJ  {'error': 'Your account has run out of searche...    0
# 927  IT8SSzYAAAAJ  {'error': 'Your account has run out of searche...    0
#
#     PL6_1 PL6_2 DE23_1_2
# 0     NaN   NaN       94
# 1     NaN   NaN      NaN
# 2       1     1      187
# 3       1   NaN      118
# 4       1   NaN      118
# ..    ...   ...      ...
# 923     1   NaN      222
# 924   NaN   NaN      NaN
# 925   NaN   NaN      166
# 926   NaN   NaN      NaN
# 927   NaN   NaN      NaN
#
# [928 rows x 8 columns]

# %%
gs_df['DE22'].isna().sum()
# Out:
# np.int64(15)

# %%
gs_df[(gs_df['DE22'] > 0) & (gs_df['PL6_1'].isna())].shape[0]
# Out:
# 131

# %%
gs_df[(gs_df['DE22'] > 0) & (gs_df['PL6_1'].isna()) & (gs_df['user_id'].isna())].shape[0]
# Out:
# 8

# %% [markdown]
# following filters were applied to fetch data from serpAPI for gs_df:
#
# 1. `user_id` is not None.
# 2. DE22 number of children is not NaN.
# 3. If DE22 > 0, then PL6_1 must also be present (not NaN).
#
# Only the rows satisfying all of the above conditions and missing article or citation data are sent to the API.

# %%
import requests

def get_serpapi_usage(api_key):
    url = "https://serpapi.com/account"
    params = {"api_key": api_key}
    r = requests.get(url, params=params)
    return r.json()

print(get_serpapi_usage(api_key))
# Out:
# {'account_id': '6492e2051e803fced9e15f80', 'api_key': 'cfade58a5d1ac10173d2536ed5a764b39c05af46ba17d70f2061c93197e22ca8', 'account_email': 'trashicontainer@gmail.com', 'account_status': 'Active', 'plan_id': 'free', 'plan_name': 'Free Plan', 'plan_monthly_price': 0.0, 'searches_per_month': 100, 'plan_searches_left': 96, 'extra_credits': 0, 'total_searches_left': 96, 'this_month_usage': 4, 'this_hour_searches': 0, 'last_hour_searches': 0, 'account_rate_limit_per_hour': 100}

# %%
def get_serpapi_usage(api_key):
    url = "https://serpapi.com/account"
    params = {"api_key": api_key}
    r = requests.get(url, params=params)
    return r.json()

print(get_serpapi_usage(api_key))
# Out:
# {'account_id': '68767b969368e57738364503', 'api_key': 'bfd2f4c34b6645eaba0883182202432a915fabee41f37b42d7f6e7140f4e7697', 'account_email': 'espin@csh.ac.at', 'account_status': 'Active', 'plan_id': 'free', 'plan_name': 'Free Plan', 'plan_monthly_price': 0.0, 'searches_per_month': 100, 'plan_searches_left': 56, 'extra_credits': 0, 'total_searches_left': 56, 'this_month_usage': 44, 'this_hour_searches': 0, 'last_hour_searches': 1, 'account_rate_limit_per_hour': 100}

# %%
def is_missing(val):
    return val is None or (isinstance(val, float) and pd.isna(val)) or (isinstance(val,(dict, list))and len(val) == 0)

# %%
# Ensure columns exist and are treated as objects (dicts/lists)
for col in ['full_articles', 'cited_by', 'citation_graph', 'author_metadata']:
    if col not in gs_df.columns:
        gs_df[col] = None
    gs_df[col] = gs_df[col].astype(object)


# Filter rows based on conditions
valid_mask = (
    pd.notna(gs_df['user_id']) &
    pd.notna(gs_df['DE22']) &
    ~((gs_df['DE22'] > 0) & pd.isna(gs_df['PL6_1']))
)

valid_rows = gs_df[valid_mask]

MAX_TOTAL_REQUESTS = 1000
total_requests = 0

for idx in valid_rows.index:
    if total_requests >= MAX_TOTAL_REQUESTS:
        print(f"[INFO] Reached quota cap of {MAX_TOTAL_REQUESTS} requests. Stopping.")
        break

    needs_articles = is_missing(gs_df.at[idx, 'full_articles'])
    needs_citation_graph = is_missing(gs_df.at[idx, 'cited_by'])
    needs_author_metadata = is_missing(gs_df.at[idx, 'author_metadata'])
    

    if needs_articles or needs_citation_graph or needs_author_metadata:
        user_id = gs_df.at[idx, 'user_id']
        #if user_id ends with __SKIP, skip this row
        if user_id.endswith("__SKIP"):
            continue
        result = fetch_articles_and_citations(user_id, api_key)

        total_requests += 1

        if needs_articles:
            if 'articles' not in result or result['articles'] is None:
                print(f"[!] No articles found for user_id {user_id}.")
            else:
                gs_df.at[idx, 'full_articles'] = result['articles']

        if needs_citation_graph:
            if 'cited_by' not in result or result['cited_by'] is None:
                print(f"[!] No citation graph found for user_id {user_id}.")
            else:
                cited_by = result.get('cited_by', {})
                gs_df.at[idx, 'citation_graph'] = cited_by.get('graph', [])
                gs_df.at[idx, 'cited_by'] = cited_by

        if needs_author_metadata:
            if 'author' not in result or result['author'] is None:
                print(f"[!] No author metadata found for user_id {user_id}.")
            else:
                gs_df.at[idx, 'author_metadata'] = result.get('author', {})
            
print(f"Total requests made: {total_requests}")
# Out:
# [!] No citation graph found for user_id OgIh5VAAAAAJ.
# [!] No author metadata found for user_id OgIh5VAAAAAJ.
# [!] No citation graph found for user_id l2zLIwMAAAAJ.
# [!] No author metadata found for user_id l2zLIwMAAAAJ.
# [!] No citation graph found for user_id YWBfMkoAAAAJ.
# [!] No author metadata found for user_id YWBfMkoAAAAJ.
# [!] No citation graph found for user_id vlvVQwsAAAAJ.
# [!] No author metadata found for user_id vlvVQwsAAAAJ.
# [!] No citation graph found for user_id B05RG_4AAAAJ.
# [!] No author metadata found for user_id B05RG_4AAAAJ.
# [!] No citation graph found for user_id hAdQif4AAAAJ.
# [!] No author metadata found for user_id hAdQif4AAAAJ.
# [!] No citation graph found for user_id 47tOoqQAAAAJ.
# [!] No author metadata found for user_id 47tOoqQAAAAJ.
# [!] No citation graph found for user_id Sabater-Lleal.
# [!] No author metadata found for user_id Sabater-Lleal.
# [!] No citation graph found for user_id IAe4K6UAAAAJ.
# [!] No author metadata found for user_id IAe4K6UAAAAJ.
# [!] No citation graph found for user_id 7fVG8EkAAAAJ.
# Total requests made: 564

# %%
user_id
# Out:
# '1z_2fvQAAAAJ'

# %%
fetch_articles_and_citations("1z_2fvQAAAAJ", api_key)
# Out:
# {'articles': [], 'cited_by': None, 'author': None, 'requests_made': 1}

# %%
gs_df.to_json("gs_df_50_first_scrape.json", orient='records', lines=True)

# %%
for i in range(10):
    articles = gs_df.loc[i, 'full_articles']
    print(f"User {gs_df.loc[i, 'user_id']} - Number of articles: {len(articles) if articles else 0}")
# Out:
# User GuhyORoAAAAJ - Number of articles: 0
# User BSkeONEAAAAJ - Number of articles: 10
# User None - Number of articles: 0
# User DCWkn9sAAAAJ - Number of articles: 66
# User UyrfibgAAAAJ - Number of articles: 295
# User jqBvlqkAAAAJ - Number of articles: 152
# User 4o8ZzvAAAAAJ - Number of articles: 34
# User CQrjj8gAAAAJ - Number of articles: 270
# User lY4m8f8AAAAJ - Number of articles: 36
# User xol-omcAAAAJ - Number of articles: 146

# %%
gs_df.head(5)
# Out:
#           ResponseId                                           DE13_1_1  \
# 0  R_4pD7OrlAt0l6mjL  https://scholar.google.com/citations?user=Guhy...
# 1  R_7OE9SfkJJ6q9jbP  https://scholar.google.com/citations?user=BSke...
# 2  R_62ojVyfY2SdzKN0  https://scholar.google.com/scholar?hl=en&as_sd...
# 3  R_2B4eUokwACUsT08  https://scholar.google.com/citations?user=DCWk...
# 4  R_2JTY94aJonph8Qx  https://scholar.google.it/citations?user=Uyrfi...
#
#         user_id                                    raw_author_data DE22 PL6_1  \
# 0  GuhyORoAAAAJ  {'search_metadata': {'id': '68703f16634a638ac3...    2   NaN
# 1  BSkeONEAAAAJ  {'search_metadata': {'id': '68703f17874d50617c...    0   NaN
# 2          None                                               None    2     1
# 3  DCWkn9sAAAAJ  {'search_metadata': {'id': '68703f19abe7eca231...    1     1
# 4  UyrfibgAAAAJ  {'search_metadata': {'id': '68703f1b95e95031e3...    1     1
#
#   PL6_2 DE23_1_2                                      full_articles  \
# 0   NaN       94                                               None
# 1   NaN      NaN  [{'title': 'GDPR Interference With Next Genera...
# 2     1      187                                               None
# 3   NaN      118  [{'title': 'Ecological impact of introduced fi...
# 4   NaN      118  [{'title': 'Agent based modeling and simulatio...
#
#                                             cited_by  \
# 0                                               None
# 1  {'table': [{'citations': {'all': 45, 'since_20...
# 2                                               None
# 3  {'table': [{'citations': {'all': 1169, 'since_...
# 4  {'table': [{'citations': {'all': 4117, 'since_...
#
#                                       citation_graph  \
# 0                                               None
# 1  [{'year': 2020, 'citations': 3}, {'year': 2021...
# 2                                               None
# 3  [{'year': 2011, 'citations': 7}, {'year': 2012...
# 4  [{'year': 2004, 'citations': 28}, {'year': 200...
#
#                                      author_metadata
# 0                                               None
# 1  {'name': 'Stavroula Rizou, Ph.D.', 'affiliatio...
# 2                                               None
# 3  {'name': 'Rocco Tiberti', 'affiliations': 'DiB...
# 4  {'name': 'Giuseppe Vizzari', 'affiliations': '...

# %%
gs_df.to_excel("gs_df_second_scrape.xlsx", index=False)

# %%
gs_df.to_json("gs_df_second_scrape.json", orient='records', lines=True)

# %%
gs_df.to_excel("gs_df_third_scrape.xlsx", index=False)
gs_df.to_json("gs_df_third_scrape.json", orient='records', lines=True)

# %%
gs_df.to_excel("gs_df_fourth_scrape.xlsx", index=False)
gs_df.to_json("gs_df_fourth_scrape.json", orient='records', lines=True)

# %%
gs_df.to_excel("gs_df_fifth_scrape.xlsx", index=False)
gs_df.to_json("gs_df_fifth_scrape.json", orient='records', lines=True)

# %% [markdown]
# something is with the userId. And I am requestng for a user?od that has been known that is not having anz values to retrieve, I need to adjust the code!

# %%
gs_df.to_excel("gs_df_sixth_scrape.xlsx", index=False)
gs_df.to_json("gs_df_sixth_scrape.json", orient='records', lines=True)

# %%
gs_df = pd.read_json("gs_df_sixth_scrape.json", orient='records', lines=True)
gs_df.head()
# Out:
#           ResponseId                                           DE13_1_1  \
# 0  R_4pD7OrlAt0l6mjL  https://scholar.google.com/citations?user=Guhy...
# 1  R_7OE9SfkJJ6q9jbP  https://scholar.google.com/citations?user=BSke...
# 2  R_62ojVyfY2SdzKN0  https://scholar.google.com/scholar?hl=en&as_sd...
# 3  R_2B4eUokwACUsT08  https://scholar.google.com/citations?user=DCWk...
# 4  R_2JTY94aJonph8Qx  https://scholar.google.it/citations?user=Uyrfi...
#
#         user_id                                    raw_author_data  DE22  \
# 0  GuhyORoAAAAJ  {'search_metadata': {'id': '68703f16634a638ac3...   2.0
# 1  BSkeONEAAAAJ  {'search_metadata': {'id': '68703f17874d50617c...   0.0
# 2          None                                               None   2.0
# 3  DCWkn9sAAAAJ  {'search_metadata': {'id': '68703f19abe7eca231...   1.0
# 4  UyrfibgAAAAJ  {'search_metadata': {'id': '68703f1b95e95031e3...   1.0
#
#    PL6_1  PL6_2  DE23_1_2                                      full_articles  \
# 0    NaN    NaN      94.0                                               None
# 1    NaN    NaN       NaN  [{'title': 'GDPR Interference With Next Genera...
# 2    1.0    1.0     187.0                                               None
# 3    1.0    NaN     118.0  [{'title': 'Ecological impact of introduced fi...
# 4    1.0    NaN     118.0  [{'title': 'Agent based modeling and simulatio...
#
#                                             cited_by  \
# 0                                               None
# 1  {'table': [{'citations': {'all': 45, 'since_20...
# 2                                               None
# 3  {'table': [{'citations': {'all': 1169, 'since_...
# 4  {'table': [{'citations': {'all': 4117, 'since_...
#
#                                       citation_graph  \
# 0                                               None
# 1  [{'year': 2020, 'citations': 3}, {'year': 2021...
# 2                                               None
# 3  [{'year': 2011, 'citations': 7}, {'year': 2012...
# 4  [{'year': 2004, 'citations': 28}, {'year': 200...
#
#                                      author_metadata
# 0                                               None
# 1  {'name': 'Stavroula Rizou, Ph.D.', 'affiliatio...
# 2                                               None
# 3  {'name': 'Rocco Tiberti', 'affiliations': 'DiB...
# 4  {'name': 'Giuseppe Vizzari', 'affiliations': '...

# %%
user_ids_to_skip = {
    "1z_2fvQAAAAJ",
    "6TjH8w4AAAAJ",
    "0000-0001-5535-5894",
    "1"
}

gs_df['user_id'] = gs_df['user_id'].apply(
    lambda uid: f"{uid}__SKIP" if str(uid) in user_ids_to_skip else uid
)

# %%
# Show all rows in gs_df where 'user_id' contains '1z_2fvQAAAAJ'
gs_df[gs_df['user_id'].astype(str).str.contains('1z_2fvQAAAAJ', na=False)]['user_id']
# Out:
# 139    1z_2fvQAAAAJ__SKIP
# Name: user_id, dtype: object

# %%
gs_df.to_excel("gs_df_seventh_scrape.xlsx", index=False)
gs_df.to_json("gs_df_seventh_scrape.json", orient='records', lines=True)

# %%
gs_df = pd.read_json("gs_df_seventh_scrape.json", orient='records', lines=True)

# %%
def is_missing_full_articles(val):
    if val is None:
        return True
    if isinstance(val, float) and pd.isna(val):
        return True
    if isinstance(val, (dict, list)) and len(val) == 0:
        return True
    return False

missing_count = gs_df['full_articles'].apply(is_missing_full_articles).sum()
print(f"Number of rows with None, NaN, or empty dict/list in 'full_articles': {missing_count}")
# Out:
# Number of rows with None, NaN, or empty dict/list in 'full_articles': 200
